# %% [markdown]
# # 주택 가격 예측

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

from matplotlib import rc

rc('font', family = 'NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
house_pr_org = pd.read_csv('data/house_price.csv')

# %%
house_pr = house_pr_org.copy()

# %%
house_pr.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
house_pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_pr.shape
# Out:
# (1460, 81)

# %%
house_pr.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %% [markdown]
# ## 데이터 전처리 Preprocessing

# %%
plt.title('Origin Sale Price Histogram', pad = 15)
sns.distplot(house_pr['SalePrice'])

# %%
plt.title('Log transformed Sale Price Histogram', pad =15)
log_SalePrice = np.log1p(house_pr['SalePrice'])
sns.distplot(log_SalePrice)

# %%
# Sale price 로그 변환 
original_SalePrice = house_pr['SalePrice']
house_pr['SalePrice'] = np.log1p(house_pr['SalePrice'])

# %%
Nu = house_pr.isnull().sum()
Nu[Nu>0].sort_values(ascending =False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
# Null 값이 너무 많은 Feature 삭제 
house_pr.drop(['Id','PoolQC','MiscFeature','Alley','Fence','FireplaceQu'], axis =1, inplace = True)

# %%
#드롭하지 않은 숫자형의 null 을 평균값으로 대체 
house_pr.fillna(house_pr.mean(), inplace = True)

# %%
# Null 값이 있는 피처명과 타입 추출 
null_column_count = house_pr.isnull().sum()[house_pr.isnull().sum() > 0]

# %%
house_pr.dtypes[null_column_count.index]
# Out:
# MasVnrType      object
# BsmtQual        object
# BsmtCond        object
# BsmtExposure    object
# BsmtFinType1    object
# BsmtFinType2    object
# Electrical      object
# GarageType      object
# GarageFinish    object
# GarageQual      object
# GarageCond      object
# dtype: object

# %%
# 문자형 피처를 원핫 인코딩으로 변환 : Null값은 None 으로 대체해줌. 

house_df_ohe = pd.get_dummies(house_pr)
house_df_ohe.shape
# Out:
# (1460, 271)

# %%
null_column_count = house_df_ohe.isnull().sum()[house_df_ohe.isnull().sum() > 0]
null_column_count
# Out:
# Series([], dtype: int64)

# %%
house_df_ohe.dtypes[null_column_count.index]
# Out:
# Series([], dtype: object)

# %% [markdown]
# ### 선형 회귀 모델 학습/예측/평가
#
# 예측 평가 방식 : RMSLE ( 실제 값과 예측 값의 오류를 로그 변환한 뒤 RMSE를 적용 )
# 실제 값과 예측값 모두 로그 변환값으로 예측 결과 오류에 RMSE만 적용하면 RMSLE가 자동으로 측정.

# %%
# 로그 변환된 RMSE 측정 함수 
def get_rmse(model):
    pred = model.predict(X_test)
    mse = mean_squared_error(y_test, pred)
    rmse = np.sqrt(mse)
    
    print(model.__class__.__name__, '로그 변환된 RMSE :', np.round(rmse, 3))
    return rmse

# %%
# 여러 모델들의 RMSE 값 한번에 반환 
def get_rmses(models) :
    rmses = []
    
    for model in models:
        rmse = get_rmse(model)
        rmses.append(rmse)
        
    return rmses

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
y_target = house_df_ohe['SalePrice']
x_feature = house_df_ohe.drop('SalePrice', axis = 1, inplace = False)

X_train, X_test, y_train, y_test = train_test_split(x_feature, y_target, test_size = 0.2, random_state = 0 )

# %%
# LinearRegression model 
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)

# Ridge model 
ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)

# Lasso model
lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso()

# %%
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models)
# Out:
# LinearRegression 로그 변환된 RMSE : 0.237
# Ridge 로그 변환된 RMSE : 0.203
# Lasso 로그 변환된 RMSE : 0.265
# [0.2365476271141981, 0.20264744779250818, 0.26543913979074485]

# %%
# 회귀 계수 상위 10개 , 하위 10개의 features  
def get_top_bottom_coef(model, n = 10):
    # coef_ 속성을 기반으로 Series 객체를 생성, index 는 칼럼명 
    coef = pd.Series(model.coef_, index = x_feature.columns)
    
    # +상위 10개, -하위 10개 의 회귀계수 추출 반환 
    coef_high = coef.sort_values(ascending =False).head(n)
    coef_low = coef.sort_values(ascending = False).tail(n)
    
    return coef_high, coef_low

# %%
# 모델별 상하위 10개의 회귀계수 와 그 features 
def visualization_coeff(models):
    # 3개 회귀 모델의 시각화 
    
    fig, axs = plt.subplots(1,3, figsize = (24,10))
    fig.tight_layout()
    
    for i, model in enumerate(models):
        coef_high, coef_low = get_top_bottom_coef(model)
        
        coef_concat = pd.concat([coef_high, coef_low])
        
        axs[i].set_title(model.__class__.__name__+'coeffiecents', size = 25)
        axs[i].tick_params(axis = "y", direction ='in', pad = -120)
        
        for label in (axs[i].get_xticklabels() + axs[i].get_yticklabels()):
            label.set_fontsize(20)
            
        sns.barplot(x = coef_concat.values, y =coef_concat.index, ax =axs[i])

# %%
rc('font', family = 'NanumGothic')
visualization_coeff(models)
