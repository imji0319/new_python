# %% [markdown]
# ## 사업보고서 데이터 추출
# 정시 공시 목록 데이터를 확인한 결과 [첨부정정]사업보고서의 경우 해당 보고서 접수번호로는 document 조회가 불가능함. 마지막 보고서가 첨부정정이 아니도록 데이터 프레임을 구성하기 위해 `final= False` 로 설정하여 중간변경 보고서까지 수집해 확인작업이 필요함.

# %%
import OpenDartReader
import configparser
import pandas as pd 
import re
import warnings

warnings.filterwarnings('ignore')
config = configparser.ConfigParser()
config.read('config.ini', encoding ='utf-8')
# Out:
# ['config.ini']

# %%
api_key = config['dart']['key']
dart = OpenDartReader(api_key)

# %%
# %%time
temp = pd.concat([dart.list(start= '2021-01-01' ,end = '2021-03-01', kind ='A',final=False),
                  dart.list(start= '2021-03-02' ,end = '2021-06-02', kind ='A',final=False),
                  dart.list(start= '2021-06-03' ,end = '2021-09-03', kind ='A',final=False)],ignore_index = True)
# Out:
# CPU times: user 4.73 s, sys: 433 ms, total: 5.16 s
# Wall time: 1min 22s

# %%
# %%time
temp = pd.concat([temp, 
                  dart.list(start= '2021-09-04' ,end = '2021-12-04', kind ='A',final=False),
                  dart.list(start= '2021-12-04' ,end = '2021-12-31', kind ='A',final=False),
                  dart.list(start= '2022-01-01', end = '2022-03-20', kind ='A',final=False)],ignore_index = True)
# Out:
# CPU times: user 2.13 s, sys: 198 ms, total: 2.33 s
# Wall time: 26.1 s

# %%
temp
# Out:
#       corp_code corp_name stock_code corp_cls              report_nm  \
# 0      00222213   포트로닉스천안     039870        E  [첨부추가]사업보고서 (2020.10)
# 1      00206039      경남스틸     039240        K        사업보고서 (2020.12)
# 2      01277113    뱅모프로덕션                   E   소액공모법인결산서류 (2020.12)
# 3      00373447     서린바이오     038070        K  [기재정정]분기보고서 (2020.09)
# 4      00261814  삼정데이타서비스                   E   소액공모법인결산서류 (2020.12)
# ...         ...       ...        ...      ...                    ...
# 14619  00209443   우리금융캐피탈     033660        E  [기재정정]사업보고서 (2020.12)
# 14620  00201432     비츠로시스     054220        K  [기재정정]반기보고서 (2021.09)
# 14621  00171636     한솔홀딩스     004150        Y  [기재정정]분기보고서 (2021.09)
# 14622  00109781      대림제지     017650        K  [기재정정]사업보고서 (2019.12)
# 14623  00109781      대림제지     017650        K  [기재정정]사업보고서 (2016.12)
#
#              rcept_no    flr_nm  rcept_dt rm
# 0      20210129000765   포트로닉스천안  20210129  연
# 1      20210226004842      경남스틸  20210226
# 2      20210226004616    뱅모프로덕션  20210226
# 3      20210226003644     서린바이오  20210226
# 4      20210226003304  삼정데이타서비스  20210226
# ...               ...       ...       ... ..
# 14619  20220111000355   우리금융캐피탈  20220111  연
# 14620  20220106000470     비츠로시스  20220106
# 14621  20220106000434     한솔홀딩스  20220106
# 14622  20220103000285      대림제지  20220103
# 14623  20220103000219      대림제지  20220103
#
# [14624 rows x 9 columns]

# %%
report_2021 = temp[temp['report_nm'].str.contains(r'사업보고서(.)*(2021.12)')]

# %%
temp[temp['corp_code']=='00206039']
# Out:
#       corp_code corp_name stock_code corp_cls        report_nm  \
# 1      00206039      경남스틸     039240        K  사업보고서 (2020.12)
# 1627   00206039      경남스틸     039240        K  분기보고서 (2021.03)
# 7848   00206039      경남스틸     039240        K  반기보고서 (2021.06)
# 11006  00206039      경남스틸     039240        K  분기보고서 (2021.09)
# 14440  00206039      경남스틸     039240        K  사업보고서 (2021.12)
#
#              rcept_no flr_nm  rcept_dt rm
# 1      20210226004842   경남스틸  20210226
# 1627   20210517000554   경남스틸  20210517
# 7848   20210817001186   경남스틸  20210817
# 11006  20211115001464   경남스틸  20211115
# 14440  20220307000359   경남스틸  20220307

# %% [markdown]
# ### 2021년 사업보고서
# 2021년 사업보고서에는 2022년 3월 20일 기준으로 아직 제출하지 않은 기업이 있을 수 있음. 3월 말까지 기한이 있기 때문.
# 또한 제출한 사업보고서에 대해 3월 이후에 계속해서 수정 및 정정이 가능해 완전한 보고서가 아닐 가능성이 잇음.

# %%
report_2021
# Out:
#       corp_code  corp_name stock_code corp_cls        report_nm  \
# 13179  00317487    에이치엘비파워     043220        K  사업보고서 (2021.12)
# 13180  01119651       엘리비젼     276240        N  사업보고서 (2021.12)
# 13181  00565215         굿센     243870        N  사업보고서 (2021.12)
# 13182  00449379     도이치모터스     067990        K  사업보고서 (2021.12)
# 13183  00536888    다믈멀티미디어     093640        K  사업보고서 (2021.12)
# ...         ...        ...        ...      ...              ...
# 14499  00648721     SNT에너지     100840        Y  사업보고서 (2021.12)
# 14500  00398792     SNT모티브     064960        Y  사업보고서 (2021.12)
# 14501  00134477     SNT중공업     003570        Y  사업보고서 (2021.12)
# 14502  01418543  케이비제20호스팩     342550        K  사업보고서 (2021.12)
# 14503  01393299  케이비제19호스팩     330990        K  사업보고서 (2021.12)
#
#              rcept_no     flr_nm  rcept_dt rm
# 13179  20220318001144    에이치엘비파워  20220318  연
# 13180  20220318001143       엘리비젼  20220318
# 13181  20220318001142         굿센  20220318
# 13182  20220318001141     도이치모터스  20220318  연
# 13183  20220318001139    다믈멀티미디어  20220318
# ...               ...        ...       ... ..
# 14499  20220218001091     SNT에너지  20220218  연
# 14500  20220218001046     SNT모티브  20220218  연
# 14501  20220218001040     SNT중공업  20220218  연
# 14502  20220218000151  케이비제20호스팩  20220218  정
# 14503  20220218000130  케이비제19호스팩  20220218  정
#
# [1271 rows x 9 columns]

# %% [markdown]
# ### 2020년 사업보고서

# %%
report_2020 = temp[temp['report_nm'].str.contains(r'사업보고서(.)*(2020.12)')]

# %%
report_2020
# Out:
#       corp_code corp_name stock_code corp_cls              report_nm  \
# 1      00206039      경남스틸     039240        K        사업보고서 (2020.12)
# 5      00105961     LG이노텍     011070        Y        사업보고서 (2020.12)
# 7      01336443      디와이씨     310870        K        사업보고서 (2020.12)
# 9      00256043    비씨월드제약     200780        K        사업보고서 (2020.12)
# 10     00978075      렌딩머신     179720        N        사업보고서 (2020.12)
# ...         ...       ...        ...      ...                    ...
# 13815  00540429      휴림로봇     090710        K  [기재정정]사업보고서 (2020.12)
# 13818  00258014  에스케이텔레시스                   E  [기재정정]사업보고서 (2020.12)
# 13824  00210980        원익     032940        K  [기재정정]사업보고서 (2020.12)
# 13838  00919966       신라젠     215600        K  [기재정정]사업보고서 (2020.12)
# 13847  00209443   우리금융캐피탈     033660        E  [기재정정]사업보고서 (2020.12)
#
#              rcept_no    flr_nm  rcept_dt  rm
# 1      20210226004842      경남스틸  20210226
# 5      20210225004545     LG이노텍  20210226  정연
# 7      20210225003830      디와이씨  20210225
# 9      20210224003918    비씨월드제약  20210224  정연
# 10     20210223002651      렌딩머신  20210223   정
# ...               ...       ...       ...  ..
# 13815  20220207000361      휴림로봇  20220207   연
# 13818  20220204000449  에스케이텔레시스  20220204   연
# 13824  20220128000266        원익  20220128   연
# 13838  20220125000451       신라젠  20220125   연
# 13847  20220111000355   우리금융캐피탈  20220111   연
#
# [3745 rows x 9 columns]

# %%
# 연장보고서 제거 
report_2020 = report_2020[~report_2020.report_nm.str.contains('연장')]

# %%
# 첨부정정 제거 
report_2020 = report_2020[~report_2020.report_nm.str.contains('첨부정정')]

# %% [markdown]
# ### 중간 변경 보고서 관련 EDA
# 기업별로 제출한 보고서의 개수를 계산한 결과 가장 많이 제출한 경우은 6번.
# 제출일자 `rcept_dt` 을 기준으로 정렬한 뒤 가장 늦게 제출한 것 선택하여 데이터로 활용

# %%
report_2020.groupby('corp_code')['rcept_no'].count().to_frame().sort_values('rcept_no')
# Out:
#            rcept_no
# corp_code
# 00100601          1
# 00550994          1
# 00551443          1
# 00551920          1
# 00554024          1
# ...             ...
# 01117413          4
# 00919966          4
# 00608802          4
# 00296005          5
# 00540429          6
#
# [2869 rows x 1 columns]

# %%
report_2020[report_2020['corp_code'] =='00540429']
# Out:
#       corp_code corp_name stock_code corp_cls              report_nm  \
# 5374   00540429      휴림로봇     090710        K  [기재정정]사업보고서 (2020.12)
# 5427   00540429      휴림로봇     090710        K        사업보고서 (2020.12)
# 3404   00540429      휴림로봇     090710        K  [기재정정]사업보고서 (2020.12)
# 3339   00540429      휴림로봇     090710        K  [기재정정]사업보고서 (2020.12)
# 3313   00540429      휴림로봇     090710        K  [기재정정]사업보고서 (2020.12)
# 13815  00540429      휴림로봇     090710        K  [기재정정]사업보고서 (2020.12)
#
#              rcept_no flr_nm  rcept_dt  rm
# 5374   20210318001341   휴림로봇  20210318  정연
# 5427   20210318001257   휴림로봇  20210318  정연
# 3404   20210405002608   휴림로봇  20210405  정연
# 3339   20210413002165   휴림로봇  20210413  정연
# 3313   20210416000363   휴림로봇  20210416  정연
# 13815  20220207000361   휴림로봇  20220207   연

# %%
report_2020 = report_2020.sort_values(['corp_code', 'rcept_dt'])

# %%
report_2020
# Out:
#       corp_code corp_name stock_code corp_cls              report_nm  \
# 3418   00100601     강원에너지     114190        K        사업보고서 (2020.12)
# 3782   00100656      강원일보                   E        사업보고서 (2020.12)
# 6757   00100814     포스코건설                   E        사업보고서 (2020.12)
# 6170   00100939    강남제비스코     000860        Y        사업보고서 (2020.12)
# 5746   00101044   에이프로젠제약     003060        Y        사업보고서 (2020.12)
# ...         ...       ...        ...      ...                    ...
# 5304   01513440    한국9호스팩     368770        K        사업보고서 (2020.12)
# 5260   01514528   신한제7호스팩     366330        K        사업보고서 (2020.12)
# 6063   01515323  LG에너지솔루션     373220        Y        사업보고서 (2020.12)
# 9850   01524507        핀텔                   E        사업보고서 (2020.12)
# 12980  01524507        핀텔                   E  [기재정정]사업보고서 (2020.12)
#
#              rcept_no    flr_nm  rcept_dt rm
# 3418   20210402002033     강원에너지  20210402  연
# 3782   20210331000666      강원일보  20210331
# 6757   20210305000704     포스코건설  20210305  연
# 6170   20210317000299    강남제비스코  20210317  연
# 5746   20210318000458   에이프로젠제약  20210318  연
# ...               ...       ...       ... ..
# 5304   20210319000079    한국9호스팩  20210319
# 5260   20210319000368   신한제7호스팩  20210319
# 6063   20210317000676  LG에너지솔루션  20210317  연
# 9850   20210713000483        핀텔  20210714  정
# 12980  20211109000077        핀텔  20211109
#
# [3625 rows x 9 columns]

# %%
report_2020 = report_2020.drop_duplicates('corp_code', keep ='last')

# %%
report_2020.to_csv('dataset/report_2020_list.csv',index =False)
