# %% [markdown]
# # Label Encoder

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from lightgbm import LGBMClassifier 
from imblearn.over_sampling import SMOTE

pd.set_option('max_columns', None)

# %%
train = pd.read_csv('card_dataset/train.csv')
test = pd.read_csv('card_dataset/test.csv')
submission = pd.read_csv('card_dataset/sample_submission.csv')

# %%
train.fillna('NAN', inplace =True)
test.fillna('NAN', inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_cols = [x for x in train.columns if train[x].dtype == 'object']
num_cols = [x for x in train.columns if train[x].dtype != 'object']

# %%
cat_cols
# Out:
# ['gender',
#  'car',
#  'reality',
#  'income_type',
#  'edu_type',
#  'family_type',
#  'house_type',
#  'occyp_type']

# %%
num_cols
# Out:
# ['index',
#  'child_num',
#  'income_total',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'FLAG_MOBIL',
#  'work_phone',
#  'phone',
#  'email',
#  'family_size',
#  'begin_month',
#  'credit']

# %%
le = LabelEncoder()

# %%
for i in cat_cols:
    print(i)
    train[i] = le.fit_transform(train[i].astype(str))
    test[i] =le.fit_transform(test[i].astype(str))
# Out:
# gender
# car
# reality
# income_type
# edu_type
# family_type
# house_type
# occyp_type

# %%
train
# Out:
#        index  gender  car  reality  child_num  income_total  income_type  \
# 0          0       0    0        0          0      202500.0            0
# 1          1       0    0        1          1      247500.0            0
# 2          2       1    1        1          0      450000.0            4
# 3          3       0    0        1          0      202500.0            0
# 4          4       0    1        1          0      157500.0            2
# ...      ...     ...  ...      ...        ...           ...          ...
# 26452  26452       0    0        0          2      225000.0            2
# 26453  26453       0    0        1          1      180000.0            4
# 26454  26454       0    1        0          0      292500.0            4
# 26455  26455       1    0        1          0      171000.0            4
# 26456  26456       0    0        0          0       81000.0            4
#
#        edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             1            1           2      -13899          -4709
# 1             4            0           1      -11380          -1540
# 2             1            1           1      -19087          -4434
# 3             4            1           1      -15088          -2092
# 4             1            1           1      -15037          -2105
# ...         ...          ...         ...         ...            ...
# 26452         4            1           1      -12079          -1984
# 26453         1            2           1      -15291          -2475
# 26454         4            0           5      -10082          -2015
# 26455         2            3           1      -10145           -107
# 26456         4            0           1      -19569          -1013
#
#        FLAG_MOBIL  work_phone  phone  email  occyp_type  family_size  \
# 0               1           0      0      0          12          2.0
# 1               1           0      0      1           8          3.0
# 2               1           0      1      0          10          2.0
# 3               1           0      1      0          15          2.0
# 4               1           0      0      0          10          2.0
# ...           ...         ...    ...    ...         ...          ...
# 26452           1           0      0      0           3          4.0
# 26453           1           0      0      0          12          2.0
# 26454           1           0      0      0           3          2.0
# 26455           1           0      0      0           8          1.0
# 26456           1           0      0      0          17          2.0
#
#        begin_month  credit
# 0             -6.0     1.0
# 1             -5.0     1.0
# 2            -22.0     2.0
# 3            -37.0     0.0
# 4            -26.0     2.0
# ...            ...     ...
# 26452         -2.0     1.0
# 26453        -47.0     2.0
# 26454        -25.0     2.0
# 26455        -59.0     2.0
# 26456         -9.0     2.0
#
# [26457 rows x 20 columns]

# %%
y = train['credit']
x = train.drop(['index','FLAG_MOBIL','credit'], axis =1)
test_x = test.drop(['index','FLAG_MOBIL'], axis = 1 )

# %%
folds = StratifiedKFold(n_splits = 5, 
                       shuffle = True , random_state = 511)
smote = SMOTE(random_state = 0 )
X_train_over, y_train_over = smote.fit_sample(x, y)

# %%
loss = []
sub = np.zeros((test_x.shape[0], 3 ))


for n_folds, (train_index, val_index) in enumerate(folds.split(X_train_over, y_train_over)):
    
    print(f'======================================={n_folds + 1 }==========================================')
    
    X_train, X_val = X_train_over.iloc[train_index], X_train_over.iloc[val_index]
    y_train, y_val = y_train_over.iloc[train_index], y_train_over.iloc[val_index]
    
    
    lgb = LGBMClassifier(n_estimators = 10000,
                        n_jobs = -1, 
                        num_leaves = 2^20,
                        max_depth = 32,
                        random_state = 512,
                        learning_rate = 0.03)
    
    lgb.fit(X_train, y_train,
           eval_set = [(X_train, y_train), (X_val, y_val)],
           early_stopping_rounds = 100,
           verbose  = 1000)
    
    y_val_onehot = pd.get_dummies(y_val)
    prediction = lgb.predict_proba(X_val)
    loss.append(log_loss(y_val_onehot, prediction))
    
    sub+= lgb.predict_proba(test_x)
    
    
    print(f'=============================================================================================\n\n')
# Out:
# =======================================1==========================================
# Training until validation scores don't improve for 100 rounds
# [1000]	training's multi_logloss: 0.555847	valid_1's multi_logloss: 0.628943
# [2000]	training's multi_logloss: 0.430339	valid_1's multi_logloss: 0.559407
# [3000]	training's multi_logloss: 0.351438	valid_1's multi_logloss: 0.525728
# [4000]	training's multi_logloss: 0.293369	valid_1's multi_logloss: 0.505351
# [5000]	training's multi_logloss: 0.250005	valid_1's multi_logloss: 0.495088
# [6000]	training's multi_logloss: 0.215872	valid_1's multi_logloss: 0.489965
# Early stopping, best iteration is:
# [6740]	training's multi_logloss: 0.194533	valid_1's multi_logloss: 0.488181
# =============================================================================================
#
#
# =======================================2==========================================
# Training until validation scores don't improve for 100 rounds
# [1000]	training's multi_logloss: 0.553975	valid_1's multi_logloss: 0.628925
# [2000]	training's multi_logloss: 0.430429	valid_1's multi_logloss: 0.559158
# [3000]	training's multi_logloss: 0.352611	valid_1's multi_logloss: 0.52685
# [4000]	training's multi_logloss: 0.295393	valid_1's multi_logloss: 0.508663
# [5000]	training's multi_logloss: 0.252295	valid_1's multi_logloss: 0.498793
# [6000]	training's multi_logloss: 0.217028	valid_1's multi_logloss: 0.492903
# Early stopping, best iteration is:
# [6556]	training's multi_logloss: 0.200915	valid_1's multi_logloss: 0.491421
# =============================================================================================
#
#
# =======================================3==========================================
# Training until validation scores don't improve for 100 rounds
# [1000]	training's multi_logloss: 0.553886	valid_1's multi_logloss: 0.63407
# [2000]	training's multi_logloss: 0.427255	valid_1's multi_logloss: 0.56511
# [3000]	training's multi_logloss: 0.349325	valid_1's multi_logloss: 0.533064
# [4000]	training's multi_logloss: 0.292857	valid_1's multi_logloss: 0.514626
# [5000]	training's multi_logloss: 0.249653	valid_1's multi_logloss: 0.504099
# [6000]	training's multi_logloss: 0.215076	valid_1's multi_logloss: 0.498131
# [7000]	training's multi_logloss: 0.186422	valid_1's multi_logloss: 0.495234
# Early stopping, best iteration is:
# [6983]	training's multi_logloss: 0.1869	valid_1's multi_logloss: 0.495163
# =============================================================================================
#
#
# =======================================4==========================================
# Training until validation scores don't improve for 100 rounds
# [1000]	training's multi_logloss: 0.553389	valid_1's multi_logloss: 0.628065
# [2000]	training's multi_logloss: 0.429193	valid_1's multi_logloss: 0.553901
# [3000]	training's multi_logloss: 0.351143	valid_1's multi_logloss: 0.520136
# [4000]	training's multi_logloss: 0.295232	valid_1's multi_logloss: 0.500962
# [5000]	training's multi_logloss: 0.252786	valid_1's multi_logloss: 0.48985
# [6000]	training's multi_logloss: 0.218262	valid_1's multi_logloss: 0.483051
# Early stopping, best iteration is:
# [6810]	training's multi_logloss: 0.193919	valid_1's multi_logloss: 0.47931
# =============================================================================================
#
#
# =======================================5==========================================
# Training until validation scores don't improve for 100 rounds
# [1000]	training's multi_logloss: 0.548154	valid_1's multi_logloss: 0.624031
# [2000]	training's multi_logloss: 0.428196	valid_1's multi_logloss: 0.556855
# [3000]	training's multi_logloss: 0.349379	valid_1's multi_logloss: 0.524365
# [4000]	training's multi_logloss: 0.293297	valid_1's multi_logloss: 0.50524
# [5000]	training's multi_logloss: 0.250601	valid_1's multi_logloss: 0.496917
# Early stopping, best iteration is:
# [5895]	training's multi_logloss: 0.219536	valid_1's multi_logloss: 0.492466
# =============================================================================================

# %%
np.mean(loss)
# Out:
# 0.48930819288163957

# %%
submission.iloc[:,1:] = sub/5

# %%
submission.to_csv('submission/encodering.csv', index = False)
