# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

train = pd.read_csv('train_features.csv')
train_label = pd.read_csv('train_labels.csv')
test= pd.read_csv('test_features.csv')
submission = pd.read_csv('sample_submission.csv')
pd.set_option('display.max_columns', None)

gb_train = train.drop('time', axis = 1, inplace =False).groupby('id')
gb_test = test.drop('time',axis =1, inplace =False).groupby('id')

# %%
def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

# %%
# times 별 집계 계산 함수 features 추가 
def splitTimes(df, Times):
    
    ids = len(df)
    df_t = pd.DataFrame()
    
    for j in range(ids):
        df_agg = pd.DataFrame()
        for i in range(600//Times):
            tmp = df[j].iloc[i*Times : i*Times + Times].drop('time', axis = 1, inplace =False)
            tmp = tmp.groupby('id').agg([percentile(0),percentile(10),percentile(20), percentile(30), 
                      percentile(40), percentile(50),percentile(60), percentile(70),
                                         percentile(80),percentile(90),percentile(100)])
            df_agg = pd.concat([df_agg, tmp], axis = 1)
            
        df_t = df_t.append(df_agg)
        
    return df_t

# %%
per_train = gb_train.agg([percentile(0),percentile(10),percentile(20), percentile(30), 
                      percentile(40), percentile(50),percentile(60), percentile(70),
                                         percentile(80),percentile(90),percentile(100)])
per_test = gb_test.agg([percentile(0),percentile(10),percentile(20), percentile(30), 
                      percentile(40), percentile(50),percentile(60), percentile(70),
                                         percentile(80),percentile(90),percentile(100)])

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split

# %%
y = train_label['label']

# %%
X_train, X_test , y_train, y_test = train_test_split(per_train, y, test_size = 0.2, 
                                                    random_state = 42)
print( y_train.nunique(), y_test.nunique())
# Out:
# 61 61

# %%
evals = [(X_test.values, y_test)]

# %%
xgb = XGBClassifier(n_estimators = 400, learning_rate = 0.05, 
                    max_depth = 8, 
                    objective = 'multi:softprob', random_state = 0)

# %%
import time
import datetime

# %%
start = time.time()

xgb.fit(X_train.values, y_train, eval_set = evals, 
       eval_metric = 'mlogloss',
       early_stopping_rounds = 100)

sec = time.time() - start
print('학습 소요 시간 : ', str(datetime.timedelta(seconds = sec)).split('.') )
# Out:
# [0]	validation_0-mlogloss:3.42662
# [1]	validation_0-mlogloss:3.15436
# [2]	validation_0-mlogloss:2.95078
# [3]	validation_0-mlogloss:2.78745
# [4]	validation_0-mlogloss:2.65497
# [5]	validation_0-mlogloss:2.53836
# [6]	validation_0-mlogloss:2.43605
# [7]	validation_0-mlogloss:2.34584
# [8]	validation_0-mlogloss:2.26476
# [9]	validation_0-mlogloss:2.19176
# [10]	validation_0-mlogloss:2.12488
# [11]	validation_0-mlogloss:2.06390
# [12]	validation_0-mlogloss:2.00595
# [13]	validation_0-mlogloss:1.95421
# [14]	validation_0-mlogloss:1.90423
# [15]	validation_0-mlogloss:1.85911
# [16]	validation_0-mlogloss:1.81500
# [17]	validation_0-mlogloss:1.77539
# [18]	validation_0-mlogloss:1.73823
# [19]	validation_0-mlogloss:1.70351
# [20]	validation_0-mlogloss:1.67096
# [21]	validation_0-mlogloss:1.63888
# [22]	validation_0-mlogloss:1.60983
# [23]	validation_0-mlogloss:1.58130
# [24]	validation_0-mlogloss:1.55440
# [25]	validation_0-mlogloss:1.52931
# [26]	validation_0-mlogloss:1.50437
# [27]	validation_0-mlogloss:1.48148
# [28]	validation_0-mlogloss:1.45973
# [29]	validation_0-mlogloss:1.43808
# [30]	validation_0-mlogloss:1.41792
# [31]	validation_0-mlogloss:1.39889
# [32]	validation_0-mlogloss:1.38086
# [33]	validation_0-mlogloss:1.36262
# [34]	validation_0-mlogloss:1.34616
# [35]	validation_0-mlogloss:1.32917
# [36]	validation_0-mlogloss:1.31377
# [37]	validation_0-mlogloss:1.29869
# [38]	validation_0-mlogloss:1.28473
# [39]	validation_0-mlogloss:1.27124
# [40]	validation_0-mlogloss:1.25843
# [41]	validation_0-mlogloss:1.24694
# [42]	validation_0-mlogloss:1.23418
# [43]	validation_0-mlogloss:1.22363
# [44]	validation_0-mlogloss:1.21288
# [45]	validation_0-mlogloss:1.20208
# [46]	validation_0-mlogloss:1.19234
# [47]	validation_0-mlogloss:1.18291
# [48]	validation_0-mlogloss:1.17420
# [49]	validation_0-mlogloss:1.16498
# [50]	validation_0-mlogloss:1.15675
# [51]	validation_0-mlogloss:1.14834
# [52]	validation_0-mlogloss:1.14076
# [53]	validation_0-mlogloss:1.13340
# [54]	validation_0-mlogloss:1.12605
# [55]	validation_0-mlogloss:1.11859
# [56]	validation_0-mlogloss:1.11151
# [57]	validation_0-mlogloss:1.10514
# [58]	validation_0-mlogloss:1.09864
# [59]	validation_0-mlogloss:1.09211
# [60]	validation_0-mlogloss:1.08593
# [61]	validation_0-mlogloss:1.08040
# [62]	validation_0-mlogloss:1.07488
# [63]	validation_0-mlogloss:1.06941
# [64]	validation_0-mlogloss:1.06472
# [65]	validation_0-mlogloss:1.05965
# [66]	validation_0-mlogloss:1.05473
# [67]	validation_0-mlogloss:1.05061
# [68]	validation_0-mlogloss:1.04623
# [69]	validation_0-mlogloss:1.04201
# [70]	validation_0-mlogloss:1.03796
# [71]	validation_0-mlogloss:1.03456
# [72]	validation_0-mlogloss:1.03038
# [73]	validation_0-mlogloss:1.02704
# [74]	validation_0-mlogloss:1.02366
# [75]	validation_0-mlogloss:1.01998
# [76]	validation_0-mlogloss:1.01661
# [77]	validation_0-mlogloss:1.01318
# [78]	validation_0-mlogloss:1.01003
# [79]	validation_0-mlogloss:1.00683
# [80]	validation_0-mlogloss:1.00396
# [81]	validation_0-mlogloss:1.00051
# [82]	validation_0-mlogloss:0.99757
# [83]	validation_0-mlogloss:0.99518
# [84]	validation_0-mlogloss:0.99237
# [85]	validation_0-mlogloss:0.99051
# [86]	validation_0-mlogloss:0.98803
# [87]	validation_0-mlogloss:0.98606
# [88]	validation_0-mlogloss:0.98413
# [89]	validation_0-mlogloss:0.98182
# [90]	validation_0-mlogloss:0.98032
# [91]	validation_0-mlogloss:0.97841
# [92]	validation_0-mlogloss:0.97641
# [93]	validation_0-mlogloss:0.97486
# [94]	validation_0-mlogloss:0.97341
# [95]	validation_0-mlogloss:0.97188
# [96]	validation_0-mlogloss:0.97063
# [97]	validation_0-mlogloss:0.96910
# [98]	validation_0-mlogloss:0.96806
# [99]	validation_0-mlogloss:0.96686
# [100]	validation_0-mlogloss:0.96566
# [101]	validation_0-mlogloss:0.96419
# [102]	validation_0-mlogloss:0.96345
# [103]	validation_0-mlogloss:0.96214
# [104]	validation_0-mlogloss:0.96108
# [105]	validation_0-mlogloss:0.95998
# [106]	validation_0-mlogloss:0.95905
# [107]	validation_0-mlogloss:0.95820
# [108]	validation_0-mlogloss:0.95767
# [109]	validation_0-mlogloss:0.95703
# [110]	validation_0-mlogloss:0.95597
# [111]	validation_0-mlogloss:0.95541
# [112]	validation_0-mlogloss:0.95478
# [113]	validation_0-mlogloss:0.95449
# [114]	validation_0-mlogloss:0.95371
# [115]	validation_0-mlogloss:0.95340
# [116]	validation_0-mlogloss:0.95256
# [117]	validation_0-mlogloss:0.95217
# [118]	validation_0-mlogloss:0.95192
# [119]	validation_0-mlogloss:0.95105
# [120]	validation_0-mlogloss:0.95101
# [121]	validation_0-mlogloss:0.94978
# [122]	validation_0-mlogloss:0.94952
# [123]	validation_0-mlogloss:0.94923
# [124]	validation_0-mlogloss:0.94838
# [125]	validation_0-mlogloss:0.94808
# [126]	validation_0-mlogloss:0.94778
# [127]	validation_0-mlogloss:0.94761
# [128]	validation_0-mlogloss:0.94723
# [129]	validation_0-mlogloss:0.94666
# [130]	validation_0-mlogloss:0.94587
# [131]	validation_0-mlogloss:0.94589
# [132]	validation_0-mlogloss:0.94537
# [133]	validation_0-mlogloss:0.94499
# [134]	validation_0-mlogloss:0.94479
# [135]	validation_0-mlogloss:0.94443
# [136]	validation_0-mlogloss:0.94438
# [137]	validation_0-mlogloss:0.94400
# [138]	validation_0-mlogloss:0.94377
# [139]	validation_0-mlogloss:0.94349
# [140]	validation_0-mlogloss:0.94357
# [141]	validation_0-mlogloss:0.94336
# [142]	validation_0-mlogloss:0.94271
# [143]	validation_0-mlogloss:0.94268
# [144]	validation_0-mlogloss:0.94283
# [145]	validation_0-mlogloss:0.94240
# [146]	validation_0-mlogloss:0.94195
# [147]	validation_0-mlogloss:0.94179
# [148]	validation_0-mlogloss:0.94156
# [149]	validation_0-mlogloss:0.94139
# [150]	validation_0-mlogloss:0.94093
# [151]	validation_0-mlogloss:0.94050
# [152]	validation_0-mlogloss:0.94036
# [153]	validation_0-mlogloss:0.94014
# [154]	validation_0-mlogloss:0.94003
# [155]	validation_0-mlogloss:0.93978
# [156]	validation_0-mlogloss:0.93951
# [157]	validation_0-mlogloss:0.93939
# [158]	validation_0-mlogloss:0.93939
# [159]	validation_0-mlogloss:0.93911
# [160]	validation_0-mlogloss:0.93891
# [161]	validation_0-mlogloss:0.93886
# [162]	validation_0-mlogloss:0.93866
# [163]	validation_0-mlogloss:0.93837
# [164]	validation_0-mlogloss:0.93832
# [165]	validation_0-mlogloss:0.93831
# [166]	validation_0-mlogloss:0.93831
# [167]	validation_0-mlogloss:0.93820
# [168]	validation_0-mlogloss:0.93822
# [169]	validation_0-mlogloss:0.93801
# [170]	validation_0-mlogloss:0.93810
# [171]	validation_0-mlogloss:0.93821
# [172]	validation_0-mlogloss:0.93817
# [173]	validation_0-mlogloss:0.93790
# [174]	validation_0-mlogloss:0.93781
# [175]	validation_0-mlogloss:0.93765
# [176]	validation_0-mlogloss:0.93786
# [177]	validation_0-mlogloss:0.93779
# [178]	validation_0-mlogloss:0.93793
# [179]	validation_0-mlogloss:0.93756
# [180]	validation_0-mlogloss:0.93755
# [181]	validation_0-mlogloss:0.93749
# [182]	validation_0-mlogloss:0.93737
# [183]	validation_0-mlogloss:0.93734
# [184]	validation_0-mlogloss:0.93763
# [185]	validation_0-mlogloss:0.93752
# [186]	validation_0-mlogloss:0.93754
# [187]	validation_0-mlogloss:0.93752
# [188]	validation_0-mlogloss:0.93764
# [189]	validation_0-mlogloss:0.93758
# [190]	validation_0-mlogloss:0.93751
# [191]	validation_0-mlogloss:0.93774
# [192]	validation_0-mlogloss:0.93795
# [193]	validation_0-mlogloss:0.93783
# [194]	validation_0-mlogloss:0.93781
# [195]	validation_0-mlogloss:0.93795
# [196]	validation_0-mlogloss:0.93790
# [197]	validation_0-mlogloss:0.93779
# [198]	validation_0-mlogloss:0.93789
# [199]	validation_0-mlogloss:0.93753
# [200]	validation_0-mlogloss:0.93741
# [201]	validation_0-mlogloss:0.93726
# [202]	validation_0-mlogloss:0.93742
# [203]	validation_0-mlogloss:0.93719
# [204]	validation_0-mlogloss:0.93722
# [205]	validation_0-mlogloss:0.93734
# [206]	validation_0-mlogloss:0.93737
# [207]	validation_0-mlogloss:0.93745
# [208]	validation_0-mlogloss:0.93719
# [209]	validation_0-mlogloss:0.93754
# [210]	validation_0-mlogloss:0.93777
# [211]	validation_0-mlogloss:0.93776
# [212]	validation_0-mlogloss:0.93785
# [213]	validation_0-mlogloss:0.93782
# [214]	validation_0-mlogloss:0.93769
# [215]	validation_0-mlogloss:0.93781
# [216]	validation_0-mlogloss:0.93791
# [217]	validation_0-mlogloss:0.93787
# [218]	validation_0-mlogloss:0.93783
# [219]	validation_0-mlogloss:0.93772
# [220]	validation_0-mlogloss:0.93748
# [221]	validation_0-mlogloss:0.93770
# [222]	validation_0-mlogloss:0.93763
# [223]	validation_0-mlogloss:0.93755
# [224]	validation_0-mlogloss:0.93776
# [225]	validation_0-mlogloss:0.93769
# [226]	validation_0-mlogloss:0.93754
# [227]	validation_0-mlogloss:0.93772
# [228]	validation_0-mlogloss:0.93784
# [229]	validation_0-mlogloss:0.93776
# [230]	validation_0-mlogloss:0.93791
# [231]	validation_0-mlogloss:0.93802
# [232]	validation_0-mlogloss:0.93796
# [233]	validation_0-mlogloss:0.93798
# [234]	validation_0-mlogloss:0.93778
# [235]	validation_0-mlogloss:0.93767
# [236]	validation_0-mlogloss:0.93754
# [237]	validation_0-mlogloss:0.93756
# [238]	validation_0-mlogloss:0.93756
# [239]	validation_0-mlogloss:0.93751
# [240]	validation_0-mlogloss:0.93740
# [241]	validation_0-mlogloss:0.93747
# [242]	validation_0-mlogloss:0.93755
# [243]	validation_0-mlogloss:0.93758
# [244]	validation_0-mlogloss:0.93760
# [245]	validation_0-mlogloss:0.93758
# [246]	validation_0-mlogloss:0.93758
# [247]	validation_0-mlogloss:0.93761
# [248]	validation_0-mlogloss:0.93766
# [249]	validation_0-mlogloss:0.93782
# [250]	validation_0-mlogloss:0.93796
# [251]	validation_0-mlogloss:0.93795
# [252]	validation_0-mlogloss:0.93805
# [253]	validation_0-mlogloss:0.93820
# [254]	validation_0-mlogloss:0.93838
# [255]	validation_0-mlogloss:0.93846
# [256]	validation_0-mlogloss:0.93857
# [257]	validation_0-mlogloss:0.93857
# [258]	validation_0-mlogloss:0.93852
# [259]	validation_0-mlogloss:0.93854
# [260]	validation_0-mlogloss:0.93863
# [261]	validation_0-mlogloss:0.93878
# [262]	validation_0-mlogloss:0.93889
# [263]	validation_0-mlogloss:0.93896
# [264]	validation_0-mlogloss:0.93906
# [265]	validation_0-mlogloss:0.93905
# [266]	validation_0-mlogloss:0.93911
# [267]	validation_0-mlogloss:0.93911
# [268]	validation_0-mlogloss:0.93923
# [269]	validation_0-mlogloss:0.93922
# [270]	validation_0-mlogloss:0.93915
# [271]	validation_0-mlogloss:0.93917
# [272]	validation_0-mlogloss:0.93925
# [273]	validation_0-mlogloss:0.93925
# [274]	validation_0-mlogloss:0.93942
# [275]	validation_0-mlogloss:0.93940
# [276]	validation_0-mlogloss:0.93956
# [277]	validation_0-mlogloss:0.93960
# [278]	validation_0-mlogloss:0.93941
# [279]	validation_0-mlogloss:0.93937
# [280]	validation_0-mlogloss:0.93939
# [281]	validation_0-mlogloss:0.93941
# [282]	validation_0-mlogloss:0.93940
# [283]	validation_0-mlogloss:0.93945
# [284]	validation_0-mlogloss:0.93953
# [285]	validation_0-mlogloss:0.93959
# [286]	validation_0-mlogloss:0.93949
# [287]	validation_0-mlogloss:0.93959
# [288]	validation_0-mlogloss:0.93938
# [289]	validation_0-mlogloss:0.93941
# [290]	validation_0-mlogloss:0.93939
# [291]	validation_0-mlogloss:0.93948
# [292]	validation_0-mlogloss:0.93936
# [293]	validation_0-mlogloss:0.93933
# [294]	validation_0-mlogloss:0.93948
# [295]	validation_0-mlogloss:0.93963
# [296]	validation_0-mlogloss:0.93968
# [297]	validation_0-mlogloss:0.93960
# [298]	validation_0-mlogloss:0.93958
# [299]	validation_0-mlogloss:0.93976
# [300]	validation_0-mlogloss:0.93958
# [301]	validation_0-mlogloss:0.93971
# [302]	validation_0-mlogloss:0.93968
# 학습 소요 시간 :  ['0:02:22', '439239']

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state = 0)

# %%
X_over, y_over = smote.fit_sample(per_train, y)

X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size = 0.2, 
                                                    random_state = 42)

# %%
evals = [(X_test.values, y_test)]
xgb2 = XGBClassifier(n_estimators = 100, learning_rate = 0.05, 
                    max_depth = 8, 
                    objective = 'multi:softprob', random_state = 0)

# %%
start = time.time()
xgb2.fit(X_train.values, y_train, eval_set = evals, 
       eval_metric = 'mlogloss',
       early_stopping_rounds = 100)

sec = time.time() - start
print('학습 소요 시간 : ', str(datetime.timedelta(seconds = sec)).split('.') )
# Out:
# [0]	validation_0-mlogloss:2.94391
# [1]	validation_0-mlogloss:2.56188
# [2]	validation_0-mlogloss:2.29923
# [3]	validation_0-mlogloss:2.09627
# [4]	validation_0-mlogloss:1.93107
# [5]	validation_0-mlogloss:1.79154
# [6]	validation_0-mlogloss:1.67113
# [7]	validation_0-mlogloss:1.56513
# [8]	validation_0-mlogloss:1.47067
# [9]	validation_0-mlogloss:1.38573
# [10]	validation_0-mlogloss:1.30844
# [11]	validation_0-mlogloss:1.23765
# [12]	validation_0-mlogloss:1.17269
# [13]	validation_0-mlogloss:1.11272
# [14]	validation_0-mlogloss:1.05716
# [15]	validation_0-mlogloss:1.00539
# [16]	validation_0-mlogloss:0.95700
# [17]	validation_0-mlogloss:0.91191
# [18]	validation_0-mlogloss:0.86919
# [19]	validation_0-mlogloss:0.82944
# [20]	validation_0-mlogloss:0.79159
# [21]	validation_0-mlogloss:0.75619
# [22]	validation_0-mlogloss:0.72263
# [23]	validation_0-mlogloss:0.69091
# [24]	validation_0-mlogloss:0.66089
# [25]	validation_0-mlogloss:0.63254
# [26]	validation_0-mlogloss:0.60564
# [27]	validation_0-mlogloss:0.58010
# [28]	validation_0-mlogloss:0.55580
# [29]	validation_0-mlogloss:0.53264
# [30]	validation_0-mlogloss:0.51062
# [31]	validation_0-mlogloss:0.48963
# [32]	validation_0-mlogloss:0.46957
# [33]	validation_0-mlogloss:0.45048
# [34]	validation_0-mlogloss:0.43236
# [35]	validation_0-mlogloss:0.41504
# [36]	validation_0-mlogloss:0.39850
# [37]	validation_0-mlogloss:0.38268
# [38]	validation_0-mlogloss:0.36766
# [39]	validation_0-mlogloss:0.35331
# [40]	validation_0-mlogloss:0.33946
# [41]	validation_0-mlogloss:0.32632
# [42]	validation_0-mlogloss:0.31373
# [43]	validation_0-mlogloss:0.30171
# [44]	validation_0-mlogloss:0.29020
# [45]	validation_0-mlogloss:0.27924
# [46]	validation_0-mlogloss:0.26881
# [47]	validation_0-mlogloss:0.25874
# [48]	validation_0-mlogloss:0.24909
# [49]	validation_0-mlogloss:0.23998
# [50]	validation_0-mlogloss:0.23115
# [51]	validation_0-mlogloss:0.22271
# [52]	validation_0-mlogloss:0.21460
# [53]	validation_0-mlogloss:0.20690
# [54]	validation_0-mlogloss:0.19942
# [55]	validation_0-mlogloss:0.19236
# [56]	validation_0-mlogloss:0.18557
# [57]	validation_0-mlogloss:0.17904
# [58]	validation_0-mlogloss:0.17279
# [59]	validation_0-mlogloss:0.16679
# [60]	validation_0-mlogloss:0.16107
# [61]	validation_0-mlogloss:0.15558
# [62]	validation_0-mlogloss:0.15033
# [63]	validation_0-mlogloss:0.14524
# [64]	validation_0-mlogloss:0.14040
# [65]	validation_0-mlogloss:0.13573
# [66]	validation_0-mlogloss:0.13129
# [67]	validation_0-mlogloss:0.12703
# [68]	validation_0-mlogloss:0.12298
# [69]	validation_0-mlogloss:0.11907
# [70]	validation_0-mlogloss:0.11525
# [71]	validation_0-mlogloss:0.11166
# [72]	validation_0-mlogloss:0.10812
# [73]	validation_0-mlogloss:0.10473
# [74]	validation_0-mlogloss:0.10153
# [75]	validation_0-mlogloss:0.09843
# [76]	validation_0-mlogloss:0.09540
# [77]	validation_0-mlogloss:0.09248
# [78]	validation_0-mlogloss:0.08969
# [79]	validation_0-mlogloss:0.08701
# [80]	validation_0-mlogloss:0.08446
# [81]	validation_0-mlogloss:0.08205
# [82]	validation_0-mlogloss:0.07973
# [83]	validation_0-mlogloss:0.07745
# [84]	validation_0-mlogloss:0.07528
# [85]	validation_0-mlogloss:0.07320
# [86]	validation_0-mlogloss:0.07118
# [87]	validation_0-mlogloss:0.06925
# [88]	validation_0-mlogloss:0.06741
# [89]	validation_0-mlogloss:0.06558
# [90]	validation_0-mlogloss:0.06389
# [91]	validation_0-mlogloss:0.06223
# [92]	validation_0-mlogloss:0.06065
# [93]	validation_0-mlogloss:0.05912
# [94]	validation_0-mlogloss:0.05764
# [95]	validation_0-mlogloss:0.05625
# [96]	validation_0-mlogloss:0.05490
# [97]	validation_0-mlogloss:0.05358
# [98]	validation_0-mlogloss:0.05231
# [99]	validation_0-mlogloss:0.05105
# 학습 소요 시간 :  ['0:50:54', '505233']

# %%
start = time.time()
xgb2.fit(X_over.values, y_over, eval_set = evals, 
       eval_metric = 'mlogloss',
       early_stopping_rounds = 100)

sec = time.time() - start
print('학습 소요 시간 : ', str(datetime.timedelta(seconds = sec)).split('.') )
# Out:
# [0]	validation_0-mlogloss:2.88839
# [1]	validation_0-mlogloss:2.50517
# [2]	validation_0-mlogloss:2.24024
# [3]	validation_0-mlogloss:2.03636
# [4]	validation_0-mlogloss:1.87002
# [5]	validation_0-mlogloss:1.72939
# [6]	validation_0-mlogloss:1.60773
# [7]	validation_0-mlogloss:1.50142
# [8]	validation_0-mlogloss:1.40631
# [9]	validation_0-mlogloss:1.32066
# [10]	validation_0-mlogloss:1.24335
# [11]	validation_0-mlogloss:1.17266
# [12]	validation_0-mlogloss:1.10796
# [13]	validation_0-mlogloss:1.04793
# [14]	validation_0-mlogloss:0.99236
# [15]	validation_0-mlogloss:0.94046
# [16]	validation_0-mlogloss:0.89238
# [17]	validation_0-mlogloss:0.84731
# [18]	validation_0-mlogloss:0.80501
# [19]	validation_0-mlogloss:0.76545
# [20]	validation_0-mlogloss:0.72822
# [21]	validation_0-mlogloss:0.69316
# [22]	validation_0-mlogloss:0.66004
# [23]	validation_0-mlogloss:0.62865
# [24]	validation_0-mlogloss:0.59896
# [25]	validation_0-mlogloss:0.57093
# [26]	validation_0-mlogloss:0.54443
# [27]	validation_0-mlogloss:0.51924
# [28]	validation_0-mlogloss:0.49534
# [29]	validation_0-mlogloss:0.47262
# [30]	validation_0-mlogloss:0.45118
# [31]	validation_0-mlogloss:0.43079
# [32]	validation_0-mlogloss:0.41133
# [33]	validation_0-mlogloss:0.39278
# [34]	validation_0-mlogloss:0.37529
# [35]	validation_0-mlogloss:0.35856
# [36]	validation_0-mlogloss:0.34260
# [37]	validation_0-mlogloss:0.32744
# [38]	validation_0-mlogloss:0.31300
# [39]	validation_0-mlogloss:0.29916
# [40]	validation_0-mlogloss:0.28599
# [41]	validation_0-mlogloss:0.27343
# [42]	validation_0-mlogloss:0.26142
# [43]	validation_0-mlogloss:0.25001
# [44]	validation_0-mlogloss:0.23908
# [45]	validation_0-mlogloss:0.22868
# [46]	validation_0-mlogloss:0.21880
# [47]	validation_0-mlogloss:0.20938
# [48]	validation_0-mlogloss:0.20036
# [49]	validation_0-mlogloss:0.19180
# [50]	validation_0-mlogloss:0.18357
# [51]	validation_0-mlogloss:0.17572
# [52]	validation_0-mlogloss:0.16825
# [53]	validation_0-mlogloss:0.16115
# [54]	validation_0-mlogloss:0.15432
# [55]	validation_0-mlogloss:0.14781
# [56]	validation_0-mlogloss:0.14152
# [57]	validation_0-mlogloss:0.13557
# [58]	validation_0-mlogloss:0.12992
# [59]	validation_0-mlogloss:0.12450
# [60]	validation_0-mlogloss:0.11932
# [61]	validation_0-mlogloss:0.11439
# [62]	validation_0-mlogloss:0.10965
# [63]	validation_0-mlogloss:0.10512
# [64]	validation_0-mlogloss:0.10077
# [65]	validation_0-mlogloss:0.09665
# [66]	validation_0-mlogloss:0.09269
# [67]	validation_0-mlogloss:0.08882
# [68]	validation_0-mlogloss:0.08511
# [69]	validation_0-mlogloss:0.08161
# [70]	validation_0-mlogloss:0.07828
# [71]	validation_0-mlogloss:0.07508
# [72]	validation_0-mlogloss:0.07203
# [73]	validation_0-mlogloss:0.06912
# [74]	validation_0-mlogloss:0.06634
# [75]	validation_0-mlogloss:0.06367
# [76]	validation_0-mlogloss:0.06111
# [77]	validation_0-mlogloss:0.05863
# [78]	validation_0-mlogloss:0.05629
# [79]	validation_0-mlogloss:0.05402
# [80]	validation_0-mlogloss:0.05183
# [81]	validation_0-mlogloss:0.04979
# [82]	validation_0-mlogloss:0.04782
# [83]	validation_0-mlogloss:0.04597
# [84]	validation_0-mlogloss:0.04415
# [85]	validation_0-mlogloss:0.04242
# [86]	validation_0-mlogloss:0.04077
# [87]	validation_0-mlogloss:0.03917
# [88]	validation_0-mlogloss:0.03765
# [89]	validation_0-mlogloss:0.03620
# [90]	validation_0-mlogloss:0.03482
# [91]	validation_0-mlogloss:0.03348
# [92]	validation_0-mlogloss:0.03220
# [93]	validation_0-mlogloss:0.03096
# [94]	validation_0-mlogloss:0.02979
# [95]	validation_0-mlogloss:0.02865
# [96]	validation_0-mlogloss:0.02757
# [97]	validation_0-mlogloss:0.02653
# [98]	validation_0-mlogloss:0.02554
# [99]	validation_0-mlogloss:0.02459
# 학습 소요 시간 :  ['4:39:25', '953482']

# %%
y_pred = xgb2.predict_proba(per_test.values)
submission.iloc[:,1:] =y_pred
submission.to_csv('submission파일/over_xgb_per.csv', index = False)

# %% [markdown]
# ### 제출 결과 : 1.1600021379

# %%
train_ids = train.id.nunique()
test_ids = test.id.nunique()

train_df = [] 
for i in range(train_ids):
    train_df.append(train.iloc[600*i : 600*i + 600])
    
test_df = []
for i in range(test_ids):
    test_df.append(test.iloc[600*i : 600*i + 600 ])

# %%
train_200 = splitTimes(train_df, 200)
test_200 = splitTimes(test_df, 200)

# %%
X_train, X_test , y_train, y_test = train_test_split(train_200, y, test_size = 0.2, 
                                                    random_state = 42)
print( y_train.nunique(), y_test.nunique())

evals = [(X_test.values, y_test)]


start = time.time()
xgb.fit(X_train.values, y_train, eval_set = evals, 
       eval_metric = 'mlogloss',
       early_stopping_rounds = 100)

sec = time.time() - start
print('학습 소요 시간 : ', str(datetime.timedelta(seconds = sec)).split('.') )
# Out:
# 61 61
# [0]	validation_0-mlogloss:3.48345
# [1]	validation_0-mlogloss:3.21176
# [2]	validation_0-mlogloss:3.01345
# [3]	validation_0-mlogloss:2.85457
# [4]	validation_0-mlogloss:2.72340
# [5]	validation_0-mlogloss:2.60933
# [6]	validation_0-mlogloss:2.50974
# [7]	validation_0-mlogloss:2.42234
# [8]	validation_0-mlogloss:2.34375
# [9]	validation_0-mlogloss:2.27158
# [10]	validation_0-mlogloss:2.20393
# [11]	validation_0-mlogloss:2.14248
# [12]	validation_0-mlogloss:2.08699
# [13]	validation_0-mlogloss:2.03585
# [14]	validation_0-mlogloss:1.98827
# [15]	validation_0-mlogloss:1.94347
# [16]	validation_0-mlogloss:1.90260
# [17]	validation_0-mlogloss:1.86461
# [18]	validation_0-mlogloss:1.82804
# [19]	validation_0-mlogloss:1.79369
# [20]	validation_0-mlogloss:1.76179
# [21]	validation_0-mlogloss:1.73104
# [22]	validation_0-mlogloss:1.70121
# [23]	validation_0-mlogloss:1.67347
# [24]	validation_0-mlogloss:1.64745
# [25]	validation_0-mlogloss:1.62270
# [26]	validation_0-mlogloss:1.59962
# [27]	validation_0-mlogloss:1.57624
# [28]	validation_0-mlogloss:1.55336
# [29]	validation_0-mlogloss:1.53156
# [30]	validation_0-mlogloss:1.51152
# [31]	validation_0-mlogloss:1.49145
# [32]	validation_0-mlogloss:1.47217
# [33]	validation_0-mlogloss:1.45452
# [34]	validation_0-mlogloss:1.43738
# [35]	validation_0-mlogloss:1.42130
# [36]	validation_0-mlogloss:1.40583
# [37]	validation_0-mlogloss:1.39060
# [38]	validation_0-mlogloss:1.37623
# [39]	validation_0-mlogloss:1.36301
# [40]	validation_0-mlogloss:1.34961
# [41]	validation_0-mlogloss:1.33776
# [42]	validation_0-mlogloss:1.32553
# [43]	validation_0-mlogloss:1.31402
# [44]	validation_0-mlogloss:1.30355
# [45]	validation_0-mlogloss:1.29280
# [46]	validation_0-mlogloss:1.28275
# [47]	validation_0-mlogloss:1.27361
# [48]	validation_0-mlogloss:1.26421
# [49]	validation_0-mlogloss:1.25494
# [50]	validation_0-mlogloss:1.24669
# [51]	validation_0-mlogloss:1.23796
# [52]	validation_0-mlogloss:1.22936
# [53]	validation_0-mlogloss:1.22161
# [54]	validation_0-mlogloss:1.21453
# [55]	validation_0-mlogloss:1.20675
# [56]	validation_0-mlogloss:1.20007
# [57]	validation_0-mlogloss:1.19346
# [58]	validation_0-mlogloss:1.18602
# [59]	validation_0-mlogloss:1.17996
# [60]	validation_0-mlogloss:1.17380
# [61]	validation_0-mlogloss:1.16782
# [62]	validation_0-mlogloss:1.16164
# [63]	validation_0-mlogloss:1.15636
# [64]	validation_0-mlogloss:1.15114
# [65]	validation_0-mlogloss:1.14593
# [66]	validation_0-mlogloss:1.14098
# [67]	validation_0-mlogloss:1.13642
# [68]	validation_0-mlogloss:1.13194
# [69]	validation_0-mlogloss:1.12773
# [70]	validation_0-mlogloss:1.12313
# [71]	validation_0-mlogloss:1.11938
# [72]	validation_0-mlogloss:1.11541
# [73]	validation_0-mlogloss:1.11114
# [74]	validation_0-mlogloss:1.10738
# [75]	validation_0-mlogloss:1.10368
# [76]	validation_0-mlogloss:1.09981
# [77]	validation_0-mlogloss:1.09657
# [78]	validation_0-mlogloss:1.09317
# [79]	validation_0-mlogloss:1.09034
# [80]	validation_0-mlogloss:1.08728
# [81]	validation_0-mlogloss:1.08423
# [82]	validation_0-mlogloss:1.08121
# [83]	validation_0-mlogloss:1.07761
# [84]	validation_0-mlogloss:1.07476
# [85]	validation_0-mlogloss:1.07224
# [86]	validation_0-mlogloss:1.06937
# [87]	validation_0-mlogloss:1.06714
# [88]	validation_0-mlogloss:1.06452
# [89]	validation_0-mlogloss:1.06202
# [90]	validation_0-mlogloss:1.05950
# [91]	validation_0-mlogloss:1.05696
# [92]	validation_0-mlogloss:1.05472
# [93]	validation_0-mlogloss:1.05275
# [94]	validation_0-mlogloss:1.05030
# [95]	validation_0-mlogloss:1.04760
# [96]	validation_0-mlogloss:1.04600
# [97]	validation_0-mlogloss:1.04418
# [98]	validation_0-mlogloss:1.04260
# [99]	validation_0-mlogloss:1.04032
# [100]	validation_0-mlogloss:1.03876
# [101]	validation_0-mlogloss:1.03698
# [102]	validation_0-mlogloss:1.03540
# [103]	validation_0-mlogloss:1.03383
# [104]	validation_0-mlogloss:1.03250
# [105]	validation_0-mlogloss:1.03117
# [106]	validation_0-mlogloss:1.02987
# [107]	validation_0-mlogloss:1.02889
# [108]	validation_0-mlogloss:1.02751
# [109]	validation_0-mlogloss:1.02585
# [110]	validation_0-mlogloss:1.02445
# [111]	validation_0-mlogloss:1.02318
# [112]	validation_0-mlogloss:1.02229
# [113]	validation_0-mlogloss:1.02091
# [114]	validation_0-mlogloss:1.01997
# [115]	validation_0-mlogloss:1.01915
# [116]	validation_0-mlogloss:1.01830
# [117]	validation_0-mlogloss:1.01749
# [118]	validation_0-mlogloss:1.01643
# [119]	validation_0-mlogloss:1.01556
# [120]	validation_0-mlogloss:1.01533
# [121]	validation_0-mlogloss:1.01433
# [122]	validation_0-mlogloss:1.01320
# [123]	validation_0-mlogloss:1.01237
# [124]	validation_0-mlogloss:1.01155
# [125]	validation_0-mlogloss:1.01073
# [126]	validation_0-mlogloss:1.01044
# [127]	validation_0-mlogloss:1.00956
# [128]	validation_0-mlogloss:1.00878
# [129]	validation_0-mlogloss:1.00815
# [130]	validation_0-mlogloss:1.00718
# [131]	validation_0-mlogloss:1.00688
# [132]	validation_0-mlogloss:1.00598
# [133]	validation_0-mlogloss:1.00553
# [134]	validation_0-mlogloss:1.00493
# [135]	validation_0-mlogloss:1.00414
# [136]	validation_0-mlogloss:1.00376
# [137]	validation_0-mlogloss:1.00351
# [138]	validation_0-mlogloss:1.00279
# [139]	validation_0-mlogloss:1.00239
# [140]	validation_0-mlogloss:1.00178
# [141]	validation_0-mlogloss:1.00114
# [142]	validation_0-mlogloss:1.00080
# [143]	validation_0-mlogloss:1.00104
# [144]	validation_0-mlogloss:1.00029
# [145]	validation_0-mlogloss:0.99983
# [146]	validation_0-mlogloss:0.99960
# [147]	validation_0-mlogloss:0.99922
# [148]	validation_0-mlogloss:0.99864
# [149]	validation_0-mlogloss:0.99816
# [150]	validation_0-mlogloss:0.99814
# [151]	validation_0-mlogloss:0.99793
# [152]	validation_0-mlogloss:0.99773
# [153]	validation_0-mlogloss:0.99773
# [154]	validation_0-mlogloss:0.99735
# [155]	validation_0-mlogloss:0.99694
# [156]	validation_0-mlogloss:0.99667
# [157]	validation_0-mlogloss:0.99627
# [158]	validation_0-mlogloss:0.99611
# [159]	validation_0-mlogloss:0.99585
# [160]	validation_0-mlogloss:0.99535
# [161]	validation_0-mlogloss:0.99535
# [162]	validation_0-mlogloss:0.99467
# [163]	validation_0-mlogloss:0.99447
# [164]	validation_0-mlogloss:0.99424
# [165]	validation_0-mlogloss:0.99385
# [166]	validation_0-mlogloss:0.99352
# [167]	validation_0-mlogloss:0.99303
# [168]	validation_0-mlogloss:0.99306
# [169]	validation_0-mlogloss:0.99273
# [170]	validation_0-mlogloss:0.99239
# [171]	validation_0-mlogloss:0.99198
# [172]	validation_0-mlogloss:0.99158
# [173]	validation_0-mlogloss:0.99146
# [174]	validation_0-mlogloss:0.99164
# [175]	validation_0-mlogloss:0.99151
# [176]	validation_0-mlogloss:0.99090
# [177]	validation_0-mlogloss:0.99069
# [178]	validation_0-mlogloss:0.99052
# [179]	validation_0-mlogloss:0.99054
# [180]	validation_0-mlogloss:0.98995
# [181]	validation_0-mlogloss:0.99010
# [182]	validation_0-mlogloss:0.98965
# [183]	validation_0-mlogloss:0.98926
# [184]	validation_0-mlogloss:0.98932
# [185]	validation_0-mlogloss:0.98914
# [186]	validation_0-mlogloss:0.98912
# [187]	validation_0-mlogloss:0.98913
# [188]	validation_0-mlogloss:0.98894
# [189]	validation_0-mlogloss:0.98882
# [190]	validation_0-mlogloss:0.98858
# [191]	validation_0-mlogloss:0.98803
# [192]	validation_0-mlogloss:0.98807
# [193]	validation_0-mlogloss:0.98815
# [194]	validation_0-mlogloss:0.98776
# [195]	validation_0-mlogloss:0.98754
# [196]	validation_0-mlogloss:0.98742
# [197]	validation_0-mlogloss:0.98728
# [198]	validation_0-mlogloss:0.98736
# [199]	validation_0-mlogloss:0.98699
# [200]	validation_0-mlogloss:0.98674
# [201]	validation_0-mlogloss:0.98648
# [202]	validation_0-mlogloss:0.98644
# [203]	validation_0-mlogloss:0.98650
# [204]	validation_0-mlogloss:0.98643
# [205]	validation_0-mlogloss:0.98649
# [206]	validation_0-mlogloss:0.98640
# [207]	validation_0-mlogloss:0.98628
# [208]	validation_0-mlogloss:0.98596
# [209]	validation_0-mlogloss:0.98594
# [210]	validation_0-mlogloss:0.98597
# [211]	validation_0-mlogloss:0.98587
# [212]	validation_0-mlogloss:0.98564
# [213]	validation_0-mlogloss:0.98547
# [214]	validation_0-mlogloss:0.98548
# [215]	validation_0-mlogloss:0.98557
# [216]	validation_0-mlogloss:0.98556
# [217]	validation_0-mlogloss:0.98543
# [218]	validation_0-mlogloss:0.98547
# [219]	validation_0-mlogloss:0.98543
# [220]	validation_0-mlogloss:0.98528
# [221]	validation_0-mlogloss:0.98518
# [222]	validation_0-mlogloss:0.98540
# [223]	validation_0-mlogloss:0.98508
# [224]	validation_0-mlogloss:0.98446
# [225]	validation_0-mlogloss:0.98447
# [226]	validation_0-mlogloss:0.98454
# [227]	validation_0-mlogloss:0.98429
# [228]	validation_0-mlogloss:0.98433
# [229]	validation_0-mlogloss:0.98420
# [230]	validation_0-mlogloss:0.98424
# [231]	validation_0-mlogloss:0.98411
# [232]	validation_0-mlogloss:0.98417
# [233]	validation_0-mlogloss:0.98429
# [234]	validation_0-mlogloss:0.98409
# [235]	validation_0-mlogloss:0.98395
# [236]	validation_0-mlogloss:0.98399
# [237]	validation_0-mlogloss:0.98389
# [238]	validation_0-mlogloss:0.98392
# [239]	validation_0-mlogloss:0.98397
# [240]	validation_0-mlogloss:0.98387
# [241]	validation_0-mlogloss:0.98374
# [242]	validation_0-mlogloss:0.98384
# [243]	validation_0-mlogloss:0.98364
# [244]	validation_0-mlogloss:0.98360
# [245]	validation_0-mlogloss:0.98372
# [246]	validation_0-mlogloss:0.98361
# [247]	validation_0-mlogloss:0.98347
# [248]	validation_0-mlogloss:0.98323
# [249]	validation_0-mlogloss:0.98315
# [250]	validation_0-mlogloss:0.98313
# [251]	validation_0-mlogloss:0.98305
# [252]	validation_0-mlogloss:0.98308
# [253]	validation_0-mlogloss:0.98289
# [254]	validation_0-mlogloss:0.98266
# [255]	validation_0-mlogloss:0.98240
# [256]	validation_0-mlogloss:0.98244
# [257]	validation_0-mlogloss:0.98222
# [258]	validation_0-mlogloss:0.98212
# [259]	validation_0-mlogloss:0.98198
# [260]	validation_0-mlogloss:0.98193
# [261]	validation_0-mlogloss:0.98181
# [262]	validation_0-mlogloss:0.98142
# [263]	validation_0-mlogloss:0.98144
# [264]	validation_0-mlogloss:0.98132
# [265]	validation_0-mlogloss:0.98126
# [266]	validation_0-mlogloss:0.98112
# [267]	validation_0-mlogloss:0.98123
# [268]	validation_0-mlogloss:0.98109
# [269]	validation_0-mlogloss:0.98087
# [270]	validation_0-mlogloss:0.98072
# [271]	validation_0-mlogloss:0.98058
# [272]	validation_0-mlogloss:0.98039
# [273]	validation_0-mlogloss:0.98024
# [274]	validation_0-mlogloss:0.98007
# [275]	validation_0-mlogloss:0.97995
# [276]	validation_0-mlogloss:0.97985
# [277]	validation_0-mlogloss:0.97967
# [278]	validation_0-mlogloss:0.97962
# [279]	validation_0-mlogloss:0.97962
# [280]	validation_0-mlogloss:0.97965
# [281]	validation_0-mlogloss:0.97970
# [282]	validation_0-mlogloss:0.97963
# [283]	validation_0-mlogloss:0.97953
# [284]	validation_0-mlogloss:0.97966
# [285]	validation_0-mlogloss:0.97965
# [286]	validation_0-mlogloss:0.97971
# [287]	validation_0-mlogloss:0.97974
# [288]	validation_0-mlogloss:0.97966
# [289]	validation_0-mlogloss:0.97939
# [290]	validation_0-mlogloss:0.97938
# [291]	validation_0-mlogloss:0.97950
# [292]	validation_0-mlogloss:0.97944
# [293]	validation_0-mlogloss:0.97939
# [294]	validation_0-mlogloss:0.97913
# [295]	validation_0-mlogloss:0.97906
# [296]	validation_0-mlogloss:0.97904
# [297]	validation_0-mlogloss:0.97901
# [298]	validation_0-mlogloss:0.97908
# [299]	validation_0-mlogloss:0.97891
# [300]	validation_0-mlogloss:0.97896
# [301]	validation_0-mlogloss:0.97897
# [302]	validation_0-mlogloss:0.97881
# [303]	validation_0-mlogloss:0.97877
# [304]	validation_0-mlogloss:0.97864
# [305]	validation_0-mlogloss:0.97845
# [306]	validation_0-mlogloss:0.97855
# [307]	validation_0-mlogloss:0.97847
# [308]	validation_0-mlogloss:0.97830
# [309]	validation_0-mlogloss:0.97814
# [310]	validation_0-mlogloss:0.97809
# [311]	validation_0-mlogloss:0.97803
# [312]	validation_0-mlogloss:0.97788
# [313]	validation_0-mlogloss:0.97761
# [314]	validation_0-mlogloss:0.97755
# [315]	validation_0-mlogloss:0.97753
# [316]	validation_0-mlogloss:0.97739
# [317]	validation_0-mlogloss:0.97718
# [318]	validation_0-mlogloss:0.97710
# [319]	validation_0-mlogloss:0.97702
# [320]	validation_0-mlogloss:0.97695
# [321]	validation_0-mlogloss:0.97698
# [322]	validation_0-mlogloss:0.97711
# [323]	validation_0-mlogloss:0.97700
# [324]	validation_0-mlogloss:0.97688
# [325]	validation_0-mlogloss:0.97672
# [326]	validation_0-mlogloss:0.97662
# [327]	validation_0-mlogloss:0.97655
# [328]	validation_0-mlogloss:0.97650
# [329]	validation_0-mlogloss:0.97639
# [330]	validation_0-mlogloss:0.97643
# [331]	validation_0-mlogloss:0.97633
# [332]	validation_0-mlogloss:0.97616
# [333]	validation_0-mlogloss:0.97611
# [334]	validation_0-mlogloss:0.97612
# [335]	validation_0-mlogloss:0.97612
# [336]	validation_0-mlogloss:0.97589
# [337]	validation_0-mlogloss:0.97585
# [338]	validation_0-mlogloss:0.97585
# [339]	validation_0-mlogloss:0.97578
# [340]	validation_0-mlogloss:0.97590
# [341]	validation_0-mlogloss:0.97586
# [342]	validation_0-mlogloss:0.97585
# [343]	validation_0-mlogloss:0.97568
# [344]	validation_0-mlogloss:0.97578
# [345]	validation_0-mlogloss:0.97567
# [346]	validation_0-mlogloss:0.97560
# [347]	validation_0-mlogloss:0.97546
# [348]	validation_0-mlogloss:0.97546
# [349]	validation_0-mlogloss:0.97548
# [350]	validation_0-mlogloss:0.97554
# [351]	validation_0-mlogloss:0.97553
# [352]	validation_0-mlogloss:0.97548
# [353]	validation_0-mlogloss:0.97550
# [354]	validation_0-mlogloss:0.97565
# [355]	validation_0-mlogloss:0.97584
# [356]	validation_0-mlogloss:0.97564
# [357]	validation_0-mlogloss:0.97555
# [358]	validation_0-mlogloss:0.97564
# [359]	validation_0-mlogloss:0.97545
# [360]	validation_0-mlogloss:0.97545
# [361]	validation_0-mlogloss:0.97541
# [362]	validation_0-mlogloss:0.97545
# [363]	validation_0-mlogloss:0.97530
# [364]	validation_0-mlogloss:0.97528
# [365]	validation_0-mlogloss:0.97521
# [366]	validation_0-mlogloss:0.97498
# [367]	validation_0-mlogloss:0.97488
# [368]	validation_0-mlogloss:0.97490
# [369]	validation_0-mlogloss:0.97485
# [370]	validation_0-mlogloss:0.97495
# [371]	validation_0-mlogloss:0.97489
# [372]	validation_0-mlogloss:0.97482
# [373]	validation_0-mlogloss:0.97484
# [374]	validation_0-mlogloss:0.97469
# [375]	validation_0-mlogloss:0.97465
# [376]	validation_0-mlogloss:0.97473
# [377]	validation_0-mlogloss:0.97465
# [378]	validation_0-mlogloss:0.97453
# [379]	validation_0-mlogloss:0.97464
# [380]	validation_0-mlogloss:0.97459
# [381]	validation_0-mlogloss:0.97454
# [382]	validation_0-mlogloss:0.97459
# [383]	validation_0-mlogloss:0.97454
# [384]	validation_0-mlogloss:0.97463
# [385]	validation_0-mlogloss:0.97465
# [386]	validation_0-mlogloss:0.97455
# [387]	validation_0-mlogloss:0.97449
# [388]	validation_0-mlogloss:0.97448
# [389]	validation_0-mlogloss:0.97442
# [390]	validation_0-mlogloss:0.97453
# [391]	validation_0-mlogloss:0.97445
# [392]	validation_0-mlogloss:0.97421
# [393]	validation_0-mlogloss:0.97429
# [394]	validation_0-mlogloss:0.97423
# [395]	validation_0-mlogloss:0.97422
# [396]	validation_0-mlogloss:0.97423
# [397]	validation_0-mlogloss:0.97415
# [398]	validation_0-mlogloss:0.97396
# [399]	validation_0-mlogloss:0.97402
# 학습 소요 시간 :  ['0:05:44', '935638']
