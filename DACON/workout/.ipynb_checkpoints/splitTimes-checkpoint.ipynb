# %% [markdown]
# # 600 Times 을 분할하여 파생변수 생성
# 600 Times을 Aggregation 하여 학습한 결과, 각 id별 한 개의 데이터만 존재.
# 중복되는 label이 있지만, 데이터셋이 부족하여 과적합의 가능성이 높음.
# 마지막 submission 을 위해 예측할 때 사용할 test 데이터셋의 shape을 고려해야함.
#
# 1. 3125 * 600 = 1,875,000 개
#     - 모든 데이터셋 전체 학습
# 2. 3125 * ( 600 / 100 ) = 18,750 개
#     - 100 타임별로 분할하여 max, min, mean 계산하여 데이터셋 구성
# 3. 3125 * ( 600 / 50 ) = 37,500 개
#     - 50 타임별 분할하여 max, min, mean 계산하여 데이터셋 구성
# 4. 3125 * ( 600 / 10 ) = 187,500 개
#     - 10 타임별 분할하여 max, min, mean 계산하여 데이터셋 구성

# %%
start = time.time()
sec = time.time()-start
times = str(datetime.timedelta(second = sec)).split('.')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import time
import datetime
pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv('train_features.csv')
test = pd.read_csv('test_features.csv')
train_label = pd.read_csv('train_labels.csv')
submission = pd.read_csv('sample_submission.csv')

# %%
ids = train.id.nunique()

# %%
df = []

# %%
for i in range(ids):
    df.append(train.iloc[600*i : 600*i + 600])

# %%
n = 1 
df[10].iloc[n*100:n*100+100].drop('time',axis = 1, inplace = False).groupby('id').agg(['max','min','mean'])
# Out:
#        acc_x                         acc_y                        acc_z  \
#          max       min      mean       max       min      mean      max
# id
# 10  0.013193 -0.881252 -0.463381 -0.468754 -0.948012 -0.750204  0.57077
#
#                              gy_x                             gy_y             \
#          min      mean        max        min       mean        max        min
# id
# 10 -0.286108  0.285101  84.239602 -85.502858  13.611083  69.527339 -140.60047
#
#                    gy_z
#         mean        max         min       mean
# id
# 10 -8.824838  57.267105 -128.040279 -16.729449

# %%
df_id = pd.DataFrame()

for i in range(3):
    tmp = df[10].iloc[i*200:i*200+200].drop('time',axis = 1, inplace = False).groupby('id').agg(['max','min','mean'])
    # tmp.reset_index(inplace = True)
    df_id = pd.concat([df_id,tmp], axis = 1 )

# %%
df_id
# Out:
#        acc_x                         acc_y                        acc_z  \
#          max       min      mean       max       min      mean      max
# id
# 10  0.013193 -1.366979 -0.694201 -0.036306 -1.004319 -0.536356  0.57077
#
#                               gy_x                               gy_y  \
#          min      mean         max         min       mean         max
# id
# 10 -0.304365  0.179037  110.085425 -128.561551 -16.647662  112.403036
#
#                               gy_z                           acc_x            \
#           min      mean        max         min      mean       max       min
# id
# 10 -140.60047 -2.487432  63.325123 -128.040279 -9.301269  0.800592 -0.280801
#
#                  acc_y                         acc_z                      \
#         mean       max       min      mean       max       min      mean
# id
# 10  0.358864 -0.674516 -1.146763 -0.864957  0.534329 -0.378424  0.043128
#
#          gy_x                            gy_y                       \
#           max         min     mean        max        min      mean
# id
# 10  88.849273 -105.346273 -2.24919  47.366107 -64.348864 -3.126423
#
#           gy_z                         acc_x                         acc_y  \
#            max       min      mean       max       min      mean       max
# id
# 10  115.249587 -94.87906 -3.946249  0.010429 -1.192412 -0.594965  0.010201
#
#                            acc_z                           gy_x             \
#          min      mean       max       min      mean        max        min
# id
# 10 -0.970939 -0.620634  0.577577 -0.244272  0.229488  104.78766 -64.642513
#
#                      gy_y                             gy_z
#          mean         max        min       mean        max        min     mean
# id
# 10  24.109274  114.751808 -50.167472  12.156522  85.943547 -77.133264  5.56261

# %%
df_id.shape
# Out:
# (1, 54)

# %%
df_agg2 = pd.DataFrame()

for j in range(ids):
    df_agg = pd.DataFrame()
    for i in range(3):
        tmp = df[j].iloc[i*200 : i*200 + 200].drop('time', axis = 1, inplace = False).groupby('id').agg(['max','min','mean'])
        df_agg = pd.concat([df_agg, tmp], axis = 1)
        
    df_agg2 = df_agg2.append(df_agg)

# %%
df_agg2
# Out:
#          acc_x                         acc_y                         acc_z  \
#            max       min      mean       max       min      mean       max
# id
# 0     1.343113  0.613582  0.939629  0.133165 -0.624113 -0.240798 -0.054876
# 1    -0.059166 -2.156208 -0.541579  0.495337 -0.997057 -0.413170  0.861091
# 2     1.219836 -1.142847  0.206800  0.469709 -0.690528 -0.102568  1.088743
# 3    -0.679208 -1.339996 -0.918718  0.210985 -0.540827 -0.173210  0.410242
# 4     0.599720 -0.831264 -0.079400  0.220760 -2.055076 -0.905563  1.057852
# ...        ...       ...       ...       ...       ...       ...       ...
# 3120  0.390798 -1.624711 -0.288550 -0.027536 -1.289257 -0.681382  0.849966
# 3121 -0.446650 -1.575455 -0.981668  0.117965 -0.600138 -0.192524  0.176047
# 3122  0.744666 -2.141936 -1.095197  1.268138 -2.036646 -0.414260  0.803950
# 3123  0.164426 -0.929133 -0.316117  1.471337  0.397902  0.885078  0.382916
# 3124  0.538809 -0.980186 -0.275555 -0.305105 -0.891517 -0.667109  0.543977
#
#                                 gy_x                               gy_y  \
#            min      mean         max         min       mean         max
# id
# 0    -0.672738 -0.344088   30.962266  -46.254836  -2.085009   69.847244
# 1    -0.522313  0.313459  176.742984 -322.482025  -3.292411  221.240277
# 2     0.073846  0.558121   73.525082 -127.845394  -5.228462  202.876776
# 3    -0.181537  0.148455  133.050586  -69.419166  14.740780  141.001242
# 4    -1.231836  0.186689  140.227116 -356.302649 -16.625429  284.952954
# ...        ...       ...         ...         ...        ...         ...
# 3120 -0.551185  0.194684  144.269756 -194.369980 -18.895973  134.585268
# 3121 -0.403201 -0.107707  155.958950  -28.736317  35.088227   48.465535
# 3122 -0.459267  0.278428  400.662632 -731.029790 -10.348042  342.797555
# 3123 -0.646863 -0.132612  168.716922 -121.756774 -12.642361  198.033474
# 3124 -0.163281  0.312278   31.017538  -33.240136  -5.343389   88.243786
#
#                                    gy_z                            acc_x  \
#              min       mean         max         min       mean       max
# id
# 0     -85.887677  -2.103937   55.953827  -65.593383   5.986721  1.284556
# 1    -315.096003  10.504189   93.343216 -179.514208  19.414557  0.316553
# 2    -228.305082 -10.437496   55.642836  -41.230252   1.949360  1.003180
# 3     -82.537304   0.312905   56.456908  -85.600536  -2.003227 -0.622250
# 4     -42.284998  24.280372  162.734781 -171.614590  10.553543 -0.335596
# ...          ...        ...         ...         ...        ...       ...
# 3120 -190.818371  -6.619741  121.958427  -70.429209  16.932698 -0.068120
# 3121  -33.757220   6.868583   18.956690  -39.777626  -4.569780 -0.608541
# 3122 -350.803519  -9.480516  453.943910 -167.145052  21.130014  0.023353
# 3123 -148.431769  10.955653  120.963282 -206.580638   1.715393  0.482880
# 3124 -134.268304 -15.040502   66.437469  -83.882730 -12.614084  0.534176
#
#                              acc_y                         acc_z            \
#            min      mean       max       min      mean       max       min
# id
# 0     0.600915  0.926688  0.176871 -0.618396 -0.223190 -0.124806 -0.754574
# 1    -2.090578 -0.924799  0.228237 -1.295598 -0.424058  0.682967 -0.923339
# 2    -1.058880 -0.223230  0.650645 -0.690990 -0.058375  1.332992  0.182810
# 3    -1.097469 -0.795698  0.218557 -0.175634  0.010345  0.598814  0.037733
# 4    -2.429109 -0.927882  1.724782 -1.176536 -0.166780  2.130765 -1.250483
# ...        ...       ...       ...       ...       ...       ...       ...
# 3120 -1.256543 -0.519626  0.168070 -0.920347 -0.580878  0.618591 -0.399849
# 3121 -1.316488 -0.960098 -0.055522 -0.609743 -0.308734  0.218621 -0.233910
# 3122 -2.578974 -1.038705  0.332237 -0.991728 -0.340465  0.681510 -0.327812
# 3123 -0.784780 -0.206824  1.393445  0.348119  0.927100  0.319316 -0.638638
# 3124 -1.004290 -0.393247 -0.197942 -0.952761 -0.645197  0.507548 -0.206757
#
#                       gy_x                               gy_y              \
#           mean         max         min       mean         max         min
# id
# 0    -0.361391   31.644123  -44.233395  -2.094340   47.749768  -62.962850
# 1     0.019893  286.624363 -325.328531  34.628383  389.608060 -306.613509
# 2     0.666484   58.294292 -164.779067 -11.851520  297.320834 -249.953944
# 3     0.459238   66.619324  -67.521419  -1.159843   60.106245  -64.618932
# 4     0.048798  613.972600 -769.076518  -1.020682  282.299140 -242.036961
# ...        ...         ...         ...        ...         ...         ...
# 3120  0.273016  148.152235 -154.996929   3.911199   41.374649 -155.554683
# 3121 -0.016939   69.083167 -119.639981   1.525050   53.341929  -31.815516
# 3122  0.224131  246.751680 -457.354607 -14.712040  302.594085 -380.819269
# 3123 -0.203966  138.962517  -81.500918  15.146909  319.723456 -138.739218
# 3124  0.258244   52.957569  -58.732727   2.872259   90.173541 -128.860544
#
#                        gy_z                            acc_x            \
#            mean         max         min       mean       max       min
# id
# 0     -3.555653   53.111086  -79.930029  -1.571326  1.344268  0.591940
# 1     12.191602  340.170199 -270.980823 -11.450534  1.234020 -2.057218
# 2     11.731286   39.325004  -44.192071   3.185429  1.024170 -1.038872
# 3     -0.366338   40.344176  -54.031077  -1.131006 -0.651887 -1.417751
# 4     10.338526  221.015193 -181.317876   5.678978 -0.280967 -1.840157
# ...         ...         ...         ...        ...       ...       ...
# 3120 -10.345032   22.402852  -79.392292 -15.042066 -0.050184 -0.116195
# 3121   2.650391   57.349878  -35.960260  -2.631068 -0.935950 -1.021059
# 3122  -2.186139  190.377461 -235.343128 -16.080427  0.001980 -2.326646
# 3123  -9.213410  158.652862  -90.543063   2.723232  0.915846 -0.879598
# 3124  17.882321   73.364306 -100.845205  10.891674  0.262762 -1.013813
#
#                    acc_y                         acc_z                      \
#           mean       max       min      mean       max       min      mean
# id
# 0     0.927670  0.161123 -0.452403 -0.191426 -0.222396 -0.786336 -0.405785
# 1    -0.833363  0.700065 -1.015935 -0.114545  0.888661 -1.019531 -0.346023
# 2     0.135938  0.357798 -0.539106 -0.086265  1.215376  0.169201  0.653431
# 3    -0.948689  0.283721 -0.482761 -0.100139  0.446024 -0.257124  0.074376
# 4    -0.969772  0.887377 -1.032658  0.061143  2.678034 -0.476367  0.372786
# ...        ...       ...       ...       ...       ...       ...       ...
# 3120 -0.093184 -0.701052 -0.775234 -0.745369  0.563254  0.508790  0.540103
# 3121 -0.981128 -0.134923 -0.274141 -0.198860  0.006005 -0.169726 -0.096668
# 3122 -1.208837  0.357366 -0.909780 -0.331864  0.625892 -0.219010  0.221996
# 3123  0.188942  1.473727  0.272406  0.828907  0.361508 -0.498550 -0.031694
# 3124 -0.633343 -0.193247 -0.900382 -0.556722  0.445601 -0.380657  0.110022
#
#             gy_x                               gy_y                         \
#              max         min       mean         max         min       mean
# id
# 0      26.455876  -38.745614  -1.416459   38.686282  -54.420882  -4.418928
# 1     138.015874 -187.735237   1.878828  150.878144 -296.239951 -17.474366
# 2      45.811820  -86.828811  -8.338872  217.047558 -237.848343   0.499840
# 3     192.765368  -54.236368  39.651565  159.083788  -73.042408  14.456225
# 4     189.454944 -286.222558   3.187196   91.220520 -243.909948  -5.663760
# ...          ...         ...        ...         ...         ...        ...
# 3120    7.924599   -8.221325  -1.164173    8.728645   -2.681961   2.256377
# 3121    8.384108  -18.984592  -2.428349   18.134477   -1.396472   1.841553
# 3122  346.061091 -343.826806  13.596091  388.749570 -351.156957  42.183164
# 3123   61.299474 -208.206497 -21.175826   66.129671 -132.585347 -36.567306
# 3124   47.983838  -50.908830  -2.444983   87.978219 -104.076676  -6.522428
#
#             gy_z
#              max         min       mean
# id
# 0      34.581731  -54.523817  -0.869073
# 1     146.241141 -179.306329  -3.784142
# 2      30.311097  -31.731169   4.025083
# 3      35.079761  -67.391967 -14.475461
# 4      93.036460 -270.581913  -2.872374
# ...          ...         ...        ...
# 3120    5.796333   -6.670557  -2.052709
# 3121   15.788652   -4.540606  -1.175865
# 3122  265.326352 -247.908573 -10.218078
# 3123  310.558507 -133.851484 -22.229381
# 3124   80.302840  -85.111657  -8.018064
#
# [3125 rows x 54 columns]

# %%
test_ids = test.id.nunique()
test_ids
# Out:
# 782

# %%
df_test = []
for i in range(test_ids):
    df_test.append(test.iloc[600*i : 600*i + 600])

# %%
df_agg_test = pd.DataFrame()

for j in range(test_ids):
    df_agg = pd.DataFrame()
    for i in range(3):
        tmp = df_test[j].iloc[i*200 : i*200 + 200].drop('time', axis = 1, inplace = False).groupby('id').agg(['max','min','mean'])
        df_agg = pd.concat([df_agg, tmp], axis = 1)
        
    df_agg_test = df_agg_test.append(df_agg)

# %%
df_agg_test
# Out:
#          acc_x                         acc_y                         acc_z  \
#            max       min      mean       max       min      mean       max
# id
# 3125 -0.275446 -1.564000 -0.989584  0.172556 -0.239870 -0.020038  0.151487
# 3126  0.444149 -1.015893 -0.536384  1.708743  0.128756  0.787744 -0.079464
# 3127  0.705013 -0.036775  0.476207  1.253612  0.493329  0.908842  0.162760
# 3128  0.171789 -1.045889 -0.527978 -0.258476 -0.780307 -0.504071  0.702574
# 3129 -0.027340 -1.691371 -0.916738  0.813046 -0.860883  0.012573  0.952330
# ...        ...       ...       ...       ...       ...       ...       ...
# 3902 -0.328758 -1.601650 -0.963907  1.608399  0.045032  0.523597  0.237183
# 3903 -0.228192 -1.632634 -0.910374  0.830672 -0.509494  0.295785  0.521008
# 3904 -0.498971 -1.302081 -0.945427  0.422296 -0.443533 -0.014616  0.319565
# 3905  1.330448  0.536568  0.946841 -0.024187 -0.580191 -0.349926  0.084615
# 3906 -0.508193 -1.266320 -0.905961  0.071348 -0.766078 -0.275239  0.621691
#
#                                 gy_x                               gy_y  \
#            min      mean         max         min       mean         max
# id
# 3125 -0.561128 -0.252037   56.953059  -27.668966  -3.283639   96.185341
# 3126 -0.856899 -0.450567   62.204081 -148.947565  -1.723688  241.240196
# 3127 -0.409663 -0.157099   32.166240  -52.327129  -5.148798   25.697690
# 3128 -0.227997  0.264410   34.672903  -50.891987   1.545244  117.490868
# 3129 -0.631258  0.167999  343.576408 -345.447240  -7.205195  226.728939
# ...        ...       ...         ...         ...        ...         ...
# 3902 -0.562072 -0.144141  247.440613 -246.150470   2.306896  152.805526
# 3903 -0.573579 -0.099253  197.196100 -114.029374  29.799778   79.733062
# 3904 -0.332901  0.018317  152.814053 -214.831199 -12.580745  114.637900
# 3905 -0.703792 -0.335912   66.788750  -45.209937   3.165419   92.467431
# 3906 -0.375468 -0.044421   73.216034 -145.237944 -43.662334   30.349189
#
#                                    gy_z                            acc_x  \
#              min       mean         max         min       mean       max
# id
# 3125  -61.862128   5.477074   27.030233  -26.785818  -1.022935 -0.407004
# 3126  -66.104760  20.541547  139.089357 -112.523057 -18.874450  0.599154
# 3127  -38.428781  -2.801515   97.211730  -23.304426   0.746534  1.682591
# 3128 -166.945655  -8.527313   83.321416 -101.961357  -3.613914  0.337281
# 3129 -181.644595   7.300365  138.130133  -97.833825   9.648396  0.015642
# ...          ...        ...         ...         ...        ...       ...
# 3902 -199.846704  -2.301501   87.761471 -241.419881 -13.068968 -0.617956
# 3903 -124.895338 -13.160317  114.004443 -142.510924  -6.541332 -0.164979
# 3904 -142.559610  -3.138103  111.376910  -99.160623   3.379071 -0.085249
# 3905  -83.950263   1.717766   55.777955  -51.905231   2.235541  1.313473
# 3906  -63.718874 -12.808795   25.432961  -49.716502  -7.610037 -0.383452
#
#                              acc_y                         acc_z            \
#            min      mean       max       min      mean       max       min
# id
# 3125 -1.498606 -0.994907  0.228040 -0.283154 -0.001015  0.236922 -0.573836
# 3126 -1.929033 -0.541366  1.319533 -0.200678  0.556989  0.671876 -1.212052
# 3127 -0.278200  0.503414  1.392445  0.490982  0.924087  0.168614 -0.426220
# 3128 -1.010192 -0.302934 -0.440219 -1.294482 -0.849260  0.561100 -0.469924
# 3129 -2.153047 -0.638771  1.562602 -0.504888  0.164811  1.037876  0.046375
# ...        ...       ...       ...       ...       ...       ...       ...
# 3902 -1.410371 -1.003655  1.473749 -0.515370  0.384248  0.123358 -0.742539
# 3903 -1.709527 -0.838057  1.180247 -0.358930  0.415692  0.380464 -0.797608
# 3904 -2.124959 -0.692983  1.236138 -0.373396  0.205314  0.939270  0.001097
# 3905  0.612104  0.950059 -0.024757 -0.564953 -0.357813  0.032080 -0.665572
# 3906 -1.409693 -0.912077  0.144179 -0.780563 -0.357732  0.424491 -0.415396
#
#                       gy_x                               gy_y              \
#           mean         max         min       mean         max         min
# id
# 3125 -0.257844   26.292960  -33.944272  -3.943326   81.163973  -74.486679
# 3126  0.029298  132.830402 -111.407600 -33.154074   75.586984  -74.930772
# 3127 -0.143381   38.082005  -48.482449   2.122991   32.775363  -35.858981
# 3128 -0.065427  119.527887 -229.072919   2.435212  118.268797 -168.031080
# 3129  0.568443  366.167357 -151.273217   0.190328  178.909961 -223.475411
# ...        ...         ...         ...        ...         ...         ...
# 3902 -0.208621  409.993103 -514.058178  16.150205  109.821291 -201.654191
# 3903 -0.139534  180.510682 -162.578569 -27.361937  117.016583  -81.508622
# 3904  0.427834   95.586340  -60.892717   0.447798  129.420821 -109.156649
# 3905 -0.348444   61.799736  -63.337676   0.734788  101.379591  -73.943136
# 3906  0.127769  344.843462  -76.237027  34.100333  186.272547  -93.574534
#
#                        gy_z                            acc_x            \
#            mean         max         min       mean       max       min
# id
# 3125   0.129699   49.981455  -35.446915  -1.781768 -0.523006 -1.419293
# 3126   3.010217  169.417650  -81.634978  29.515904  0.627571 -1.300517
# 3127  -3.062248   69.327401 -104.306233  -2.325029  2.972063 -0.792916
# 3128  -2.396723  167.860762 -117.297766   3.530856 -0.859231 -0.951533
# 3129  -6.919568   81.760936 -125.598600   8.433669 -0.231068 -1.196514
# ...         ...         ...         ...        ...       ...       ...
# 3902 -14.647903  106.118337 -151.490333  -4.469883  0.427159 -2.050254
# 3903  20.966057  147.295683 -142.721146   2.673255  1.659451 -1.422074
# 3904  -3.459198  251.344358 -150.012379   3.078675 -0.417436 -0.963581
# 3905  -2.664789   58.041427  -36.514387   0.717192  1.438345  0.607731
# 3906  25.394317  101.996940 -103.093919   1.590423  0.224194 -1.534616
#
#                    acc_y                         acc_z                      \
#           mean       max       min      mean       max       min      mean
# id
# 3125 -1.071700  0.193753 -0.470937 -0.037669  0.286182 -0.479622 -0.186897
# 3126 -0.490779  1.316575  0.004112  0.491751  0.652014 -0.124548  0.207992
# 3127  0.541219  1.941820  0.219008  0.878526  0.644154 -0.484614 -0.122815
# 3128 -0.901896 -0.407198 -0.523102 -0.478338 -0.065940 -0.144565 -0.104524
# 3129 -0.660411  1.137177 -0.399686  0.370222  0.928664  0.032657  0.467464
# ...        ...       ...       ...       ...       ...       ...       ...
# 3902 -0.754336  3.057501 -1.414874  0.556947  0.147168 -1.517656 -0.361716
# 3903 -0.077762  1.549890 -1.247963  0.402330  0.713875 -0.996954 -0.081748
# 3904 -0.621167  0.706068 -0.134762  0.408648  0.664791  0.172553  0.489155
# 3905  0.979809  0.076427 -0.537070 -0.255187  0.097833 -0.774209 -0.384346
# 3906 -0.527219  0.095751 -0.958351 -0.474762  1.033111 -0.539595  0.340341
#
#             gy_x                               gy_y                         \
#              max         min       mean         max         min       mean
# id
# 3125   33.392007  -50.429364  -2.328420   76.701484  -81.607713   2.588844
# 3126  105.192311 -273.572486 -18.346815   95.960960  -97.100707  -2.627447
# 3127  160.426058  -99.799971  -3.513427   74.530763  -98.420987  -0.890592
# 3128   12.024567  -17.399751  -1.554719   31.121231  -21.460717   1.969129
# 3129  272.006008 -181.330944   2.720253   81.145669 -107.681252   3.946300
# ...          ...         ...        ...         ...         ...        ...
# 3902  749.793156 -677.830890  -2.802223  220.936927 -212.399091  20.605634
# 3903  413.572371 -265.501904  16.612603  225.268834 -205.407503   4.155495
# 3904  180.002544  -27.943454   9.849787   27.823478  -60.675901  -0.379691
# 3905   63.956191  -58.480099   3.776818   92.302605  -75.978938  -4.012663
# 3906   55.945778 -161.399629 -24.880497   98.816984 -112.020378 -23.578347
#
#             gy_z
#              max         min       mean
# id
# 3125   29.969637  -34.129517  -3.197346
# 3126   83.342859 -147.597574 -21.455190
# 3127   60.389516 -154.477074   0.398971
# 3128   13.936998  -13.380842   0.010103
# 3129   64.321940 -125.388347  -0.845570
# ...          ...         ...        ...
# 3902  214.192019 -192.916007  16.249815
# 3903  253.689077 -164.337764  43.684500
# 3904  103.069189  -80.480616  -0.652498
# 3905   54.505497  -39.750014  -0.155793
# 3906   88.296573 -190.358982 -15.573734
#
# [782 rows x 54 columns]

# %%
from xgboost import XGBClassifier
from sklearn.metrics import log_loss

# %%
y = train_label['label']

# %%
xgb = XGBClassifier(n_estimators = 400, learning_rate = 0.1, 
                            max_depth = 6,objective = 'multi:softprob', random_state = 0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test , y_train, y_test = train_test_split(df_agg2, y, test_size = 0.2, random_state = 0)
evals = [(X_test.values, y_test)]

# %%
X = df_agg2.values

# %%
start = time.time()
xgb.fit(X, y,
            eval_metric = 'mlogloss', 
            eval_set= evals, 
            early_stopping_rounds = 100)

sec = time.time()-start
times = str(datetime.timedelta(seconds = sec)).split('.')

print('소요시간 : ', times)
# Out:
# [0]	validation_0-mlogloss:2.86677
# [1]	validation_0-mlogloss:2.50121
# [2]	validation_0-mlogloss:2.21854
# [3]	validation_0-mlogloss:1.99123
# [4]	validation_0-mlogloss:1.79814
# [5]	validation_0-mlogloss:1.63860
# [6]	validation_0-mlogloss:1.49750
# [7]	validation_0-mlogloss:1.37367
# [8]	validation_0-mlogloss:1.26377
# [9]	validation_0-mlogloss:1.16694
# [10]	validation_0-mlogloss:1.08088
# [11]	validation_0-mlogloss:1.00259
# [12]	validation_0-mlogloss:0.93184
# [13]	validation_0-mlogloss:0.86698
# [14]	validation_0-mlogloss:0.80885
# [15]	validation_0-mlogloss:0.75487
# [16]	validation_0-mlogloss:0.70520
# [17]	validation_0-mlogloss:0.65916
# [18]	validation_0-mlogloss:0.61661
# [19]	validation_0-mlogloss:0.57874
# [20]	validation_0-mlogloss:0.54232
# [21]	validation_0-mlogloss:0.50940
# [22]	validation_0-mlogloss:0.47740
# [23]	validation_0-mlogloss:0.44864
# [24]	validation_0-mlogloss:0.42246
# [25]	validation_0-mlogloss:0.39783
# [26]	validation_0-mlogloss:0.37414
# [27]	validation_0-mlogloss:0.35227
# [28]	validation_0-mlogloss:0.33304
# [29]	validation_0-mlogloss:0.31450
# [30]	validation_0-mlogloss:0.29700
# [31]	validation_0-mlogloss:0.28127
# [32]	validation_0-mlogloss:0.26601
# [33]	validation_0-mlogloss:0.25215
# [34]	validation_0-mlogloss:0.23845
# [35]	validation_0-mlogloss:0.22647
# [36]	validation_0-mlogloss:0.21483
# [37]	validation_0-mlogloss:0.20394
# [38]	validation_0-mlogloss:0.19383
# [39]	validation_0-mlogloss:0.18429
# [40]	validation_0-mlogloss:0.17563
# [41]	validation_0-mlogloss:0.16736
# [42]	validation_0-mlogloss:0.15958
# [43]	validation_0-mlogloss:0.15252
# [44]	validation_0-mlogloss:0.14609
# [45]	validation_0-mlogloss:0.13983
# [46]	validation_0-mlogloss:0.13377
# [47]	validation_0-mlogloss:0.12814
# [48]	validation_0-mlogloss:0.12279
# [49]	validation_0-mlogloss:0.11775
# [50]	validation_0-mlogloss:0.11312
# [51]	validation_0-mlogloss:0.10870
# [52]	validation_0-mlogloss:0.10437
# [53]	validation_0-mlogloss:0.09996
# [54]	validation_0-mlogloss:0.09610
# [55]	validation_0-mlogloss:0.09277
# [56]	validation_0-mlogloss:0.08926
# [57]	validation_0-mlogloss:0.08596
# [58]	validation_0-mlogloss:0.08278
# [59]	validation_0-mlogloss:0.07987
# [60]	validation_0-mlogloss:0.07755
# [61]	validation_0-mlogloss:0.07515
# [62]	validation_0-mlogloss:0.07278
# [63]	validation_0-mlogloss:0.07054
# [64]	validation_0-mlogloss:0.06832
# [65]	validation_0-mlogloss:0.06625
# [66]	validation_0-mlogloss:0.06434
# [67]	validation_0-mlogloss:0.06257
# [68]	validation_0-mlogloss:0.06084
# [69]	validation_0-mlogloss:0.05932
# [70]	validation_0-mlogloss:0.05763
# [71]	validation_0-mlogloss:0.05610
# [72]	validation_0-mlogloss:0.05461
# [73]	validation_0-mlogloss:0.05322
# [74]	validation_0-mlogloss:0.05172
# [75]	validation_0-mlogloss:0.05067
# [76]	validation_0-mlogloss:0.04954
# [77]	validation_0-mlogloss:0.04832
# [78]	validation_0-mlogloss:0.04727
# [79]	validation_0-mlogloss:0.04625
# [80]	validation_0-mlogloss:0.04527
# [81]	validation_0-mlogloss:0.04418
# [82]	validation_0-mlogloss:0.04332
# [83]	validation_0-mlogloss:0.04235
# [84]	validation_0-mlogloss:0.04151
# [85]	validation_0-mlogloss:0.04064
# [86]	validation_0-mlogloss:0.03979
# [87]	validation_0-mlogloss:0.03909
# [88]	validation_0-mlogloss:0.03837
# [89]	validation_0-mlogloss:0.03759
# [90]	validation_0-mlogloss:0.03685
# [91]	validation_0-mlogloss:0.03613
# [92]	validation_0-mlogloss:0.03551
# [93]	validation_0-mlogloss:0.03491
# [94]	validation_0-mlogloss:0.03426
# [95]	validation_0-mlogloss:0.03361
# [96]	validation_0-mlogloss:0.03305
# [97]	validation_0-mlogloss:0.03253
# [98]	validation_0-mlogloss:0.03198
# [99]	validation_0-mlogloss:0.03149
# [100]	validation_0-mlogloss:0.03106
# [101]	validation_0-mlogloss:0.03057
# [102]	validation_0-mlogloss:0.03012
# [103]	validation_0-mlogloss:0.02974
# [104]	validation_0-mlogloss:0.02935
# [105]	validation_0-mlogloss:0.02895
# [106]	validation_0-mlogloss:0.02857
# [107]	validation_0-mlogloss:0.02821
# [108]	validation_0-mlogloss:0.02788
# [109]	validation_0-mlogloss:0.02750
# [110]	validation_0-mlogloss:0.02720
# [111]	validation_0-mlogloss:0.02684
# [112]	validation_0-mlogloss:0.02649
# [113]	validation_0-mlogloss:0.02618
# [114]	validation_0-mlogloss:0.02592
# [115]	validation_0-mlogloss:0.02562
# [116]	validation_0-mlogloss:0.02531
# [117]	validation_0-mlogloss:0.02501
# [118]	validation_0-mlogloss:0.02476
# [119]	validation_0-mlogloss:0.02452
# [120]	validation_0-mlogloss:0.02425
# [121]	validation_0-mlogloss:0.02401
# [122]	validation_0-mlogloss:0.02374
# [123]	validation_0-mlogloss:0.02354
# [124]	validation_0-mlogloss:0.02335
# [125]	validation_0-mlogloss:0.02315
# [126]	validation_0-mlogloss:0.02293
# [127]	validation_0-mlogloss:0.02274
# [128]	validation_0-mlogloss:0.02254
# [129]	validation_0-mlogloss:0.02232
# [130]	validation_0-mlogloss:0.02215
# [131]	validation_0-mlogloss:0.02196
# [132]	validation_0-mlogloss:0.02178
# [133]	validation_0-mlogloss:0.02158
# [134]	validation_0-mlogloss:0.02140
# [135]	validation_0-mlogloss:0.02122
# [136]	validation_0-mlogloss:0.02105
# [137]	validation_0-mlogloss:0.02085
# [138]	validation_0-mlogloss:0.02069
# [139]	validation_0-mlogloss:0.02054
# [140]	validation_0-mlogloss:0.02040
# [141]	validation_0-mlogloss:0.02024
# [142]	validation_0-mlogloss:0.02009
# [143]	validation_0-mlogloss:0.01994
# [144]	validation_0-mlogloss:0.01976
# [145]	validation_0-mlogloss:0.01962
# [146]	validation_0-mlogloss:0.01951
# [147]	validation_0-mlogloss:0.01938
# [148]	validation_0-mlogloss:0.01924
# [149]	validation_0-mlogloss:0.01913
# [150]	validation_0-mlogloss:0.01900
# [151]	validation_0-mlogloss:0.01886
# [152]	validation_0-mlogloss:0.01873
# [153]	validation_0-mlogloss:0.01861
# [154]	validation_0-mlogloss:0.01848
# [155]	validation_0-mlogloss:0.01837
# [156]	validation_0-mlogloss:0.01825
# [157]	validation_0-mlogloss:0.01814
# [158]	validation_0-mlogloss:0.01802
# [159]	validation_0-mlogloss:0.01792
# [160]	validation_0-mlogloss:0.01780
# [161]	validation_0-mlogloss:0.01770
# [162]	validation_0-mlogloss:0.01760
# [163]	validation_0-mlogloss:0.01747
# [164]	validation_0-mlogloss:0.01738
# [165]	validation_0-mlogloss:0.01727
# [166]	validation_0-mlogloss:0.01719
# [167]	validation_0-mlogloss:0.01707
# [168]	validation_0-mlogloss:0.01699
# [169]	validation_0-mlogloss:0.01689
# [170]	validation_0-mlogloss:0.01680
# [171]	validation_0-mlogloss:0.01671
# [172]	validation_0-mlogloss:0.01663
# [173]	validation_0-mlogloss:0.01655
# [174]	validation_0-mlogloss:0.01647
# [175]	validation_0-mlogloss:0.01639
# [176]	validation_0-mlogloss:0.01631
# [177]	validation_0-mlogloss:0.01621
# [178]	validation_0-mlogloss:0.01613
# [179]	validation_0-mlogloss:0.01605
# [180]	validation_0-mlogloss:0.01597
# [181]	validation_0-mlogloss:0.01592
# [182]	validation_0-mlogloss:0.01584
# [183]	validation_0-mlogloss:0.01577
# [184]	validation_0-mlogloss:0.01571
# [185]	validation_0-mlogloss:0.01565
# [186]	validation_0-mlogloss:0.01557
# [187]	validation_0-mlogloss:0.01550
# [188]	validation_0-mlogloss:0.01545
# [189]	validation_0-mlogloss:0.01538
# [190]	validation_0-mlogloss:0.01531
# [191]	validation_0-mlogloss:0.01526
# [192]	validation_0-mlogloss:0.01519
# [193]	validation_0-mlogloss:0.01512
# [194]	validation_0-mlogloss:0.01505
# [195]	validation_0-mlogloss:0.01501
# [196]	validation_0-mlogloss:0.01494
# [197]	validation_0-mlogloss:0.01488
# [198]	validation_0-mlogloss:0.01482
# [199]	validation_0-mlogloss:0.01475
# [200]	validation_0-mlogloss:0.01469
# [201]	validation_0-mlogloss:0.01465
# [202]	validation_0-mlogloss:0.01459
# [203]	validation_0-mlogloss:0.01453
# [204]	validation_0-mlogloss:0.01447
# [205]	validation_0-mlogloss:0.01443
# [206]	validation_0-mlogloss:0.01438
# [207]	validation_0-mlogloss:0.01434
# [208]	validation_0-mlogloss:0.01429
# [209]	validation_0-mlogloss:0.01425
# [210]	validation_0-mlogloss:0.01420
# [211]	validation_0-mlogloss:0.01417
# [212]	validation_0-mlogloss:0.01412
# [213]	validation_0-mlogloss:0.01407
# [214]	validation_0-mlogloss:0.01401
# [215]	validation_0-mlogloss:0.01397
# [216]	validation_0-mlogloss:0.01392
# [217]	validation_0-mlogloss:0.01387
# [218]	validation_0-mlogloss:0.01383
# [219]	validation_0-mlogloss:0.01377
# [220]	validation_0-mlogloss:0.01374
# [221]	validation_0-mlogloss:0.01369
# [222]	validation_0-mlogloss:0.01366
# [223]	validation_0-mlogloss:0.01361
# [224]	validation_0-mlogloss:0.01356
# [225]	validation_0-mlogloss:0.01353
# [226]	validation_0-mlogloss:0.01349
# [227]	validation_0-mlogloss:0.01345
# [228]	validation_0-mlogloss:0.01341
# [229]	validation_0-mlogloss:0.01337
# [230]	validation_0-mlogloss:0.01333
# [231]	validation_0-mlogloss:0.01330
# [232]	validation_0-mlogloss:0.01326
# [233]	validation_0-mlogloss:0.01323
# [234]	validation_0-mlogloss:0.01319
# [235]	validation_0-mlogloss:0.01316
# [236]	validation_0-mlogloss:0.01312
# [237]	validation_0-mlogloss:0.01309
# [238]	validation_0-mlogloss:0.01307
# [239]	validation_0-mlogloss:0.01303
# [240]	validation_0-mlogloss:0.01300
# [241]	validation_0-mlogloss:0.01297
# [242]	validation_0-mlogloss:0.01295
# [243]	validation_0-mlogloss:0.01292
# [244]	validation_0-mlogloss:0.01289
# [245]	validation_0-mlogloss:0.01286
# [246]	validation_0-mlogloss:0.01283
# [247]	validation_0-mlogloss:0.01280
# [248]	validation_0-mlogloss:0.01277
# [249]	validation_0-mlogloss:0.01275
# [250]	validation_0-mlogloss:0.01273
# [251]	validation_0-mlogloss:0.01269
# [252]	validation_0-mlogloss:0.01267
# [253]	validation_0-mlogloss:0.01265
# [254]	validation_0-mlogloss:0.01262
# [255]	validation_0-mlogloss:0.01259
# [256]	validation_0-mlogloss:0.01257
# [257]	validation_0-mlogloss:0.01254
# [258]	validation_0-mlogloss:0.01251
# [259]	validation_0-mlogloss:0.01248
# [260]	validation_0-mlogloss:0.01246
# [261]	validation_0-mlogloss:0.01243
# [262]	validation_0-mlogloss:0.01239
# [263]	validation_0-mlogloss:0.01236
# [264]	validation_0-mlogloss:0.01234
# [265]	validation_0-mlogloss:0.01231
# [266]	validation_0-mlogloss:0.01229
# [267]	validation_0-mlogloss:0.01227
# [268]	validation_0-mlogloss:0.01225
# [269]	validation_0-mlogloss:0.01222
# [270]	validation_0-mlogloss:0.01219
# [271]	validation_0-mlogloss:0.01217
# [272]	validation_0-mlogloss:0.01215
# [273]	validation_0-mlogloss:0.01213
# [274]	validation_0-mlogloss:0.01210
# [275]	validation_0-mlogloss:0.01208
# [276]	validation_0-mlogloss:0.01205
# [277]	validation_0-mlogloss:0.01203
# [278]	validation_0-mlogloss:0.01201
# [279]	validation_0-mlogloss:0.01199
# [280]	validation_0-mlogloss:0.01196
# [281]	validation_0-mlogloss:0.01194
# [282]	validation_0-mlogloss:0.01192
# [283]	validation_0-mlogloss:0.01190
# [284]	validation_0-mlogloss:0.01188
# [285]	validation_0-mlogloss:0.01186
# [286]	validation_0-mlogloss:0.01184
# [287]	validation_0-mlogloss:0.01182
# [288]	validation_0-mlogloss:0.01180
# [289]	validation_0-mlogloss:0.01178
# [290]	validation_0-mlogloss:0.01177
# [291]	validation_0-mlogloss:0.01175
# [292]	validation_0-mlogloss:0.01173
# [293]	validation_0-mlogloss:0.01171
# [294]	validation_0-mlogloss:0.01169
# [295]	validation_0-mlogloss:0.01167
# [296]	validation_0-mlogloss:0.01165
# [297]	validation_0-mlogloss:0.01163
# [298]	validation_0-mlogloss:0.01161
# [299]	validation_0-mlogloss:0.01159
# [300]	validation_0-mlogloss:0.01157
# [301]	validation_0-mlogloss:0.01156
# [302]	validation_0-mlogloss:0.01154
# [303]	validation_0-mlogloss:0.01152
# [304]	validation_0-mlogloss:0.01151
# [305]	validation_0-mlogloss:0.01150
# [306]	validation_0-mlogloss:0.01148
# [307]	validation_0-mlogloss:0.01146
# [308]	validation_0-mlogloss:0.01144
# [309]	validation_0-mlogloss:0.01143
# [310]	validation_0-mlogloss:0.01141
# [311]	validation_0-mlogloss:0.01140
# [312]	validation_0-mlogloss:0.01138
# [313]	validation_0-mlogloss:0.01136
# [314]	validation_0-mlogloss:0.01135
# [315]	validation_0-mlogloss:0.01133
# [316]	validation_0-mlogloss:0.01132
# [317]	validation_0-mlogloss:0.01130
# [318]	validation_0-mlogloss:0.01128
# [319]	validation_0-mlogloss:0.01127
# [320]	validation_0-mlogloss:0.01126
# [321]	validation_0-mlogloss:0.01125
# [322]	validation_0-mlogloss:0.01123
# [323]	validation_0-mlogloss:0.01122
# [324]	validation_0-mlogloss:0.01120
# [325]	validation_0-mlogloss:0.01119
# [326]	validation_0-mlogloss:0.01117
# [327]	validation_0-mlogloss:0.01116
# [328]	validation_0-mlogloss:0.01115
# [329]	validation_0-mlogloss:0.01113
# [330]	validation_0-mlogloss:0.01112
# [331]	validation_0-mlogloss:0.01111
# [332]	validation_0-mlogloss:0.01109
# [333]	validation_0-mlogloss:0.01107
# [334]	validation_0-mlogloss:0.01106
# [335]	validation_0-mlogloss:0.01104
# [336]	validation_0-mlogloss:0.01102
# [337]	validation_0-mlogloss:0.01101
# [338]	validation_0-mlogloss:0.01100
# [339]	validation_0-mlogloss:0.01098
# [340]	validation_0-mlogloss:0.01096
# [341]	validation_0-mlogloss:0.01095
# [342]	validation_0-mlogloss:0.01094
# [343]	validation_0-mlogloss:0.01092
# [344]	validation_0-mlogloss:0.01091
# [345]	validation_0-mlogloss:0.01090
# [346]	validation_0-mlogloss:0.01089
# [347]	validation_0-mlogloss:0.01087
# [348]	validation_0-mlogloss:0.01086
# [349]	validation_0-mlogloss:0.01085
# [350]	validation_0-mlogloss:0.01083
# [351]	validation_0-mlogloss:0.01082
# [352]	validation_0-mlogloss:0.01081
# [353]	validation_0-mlogloss:0.01079
# [354]	validation_0-mlogloss:0.01078
# [355]	validation_0-mlogloss:0.01077
# [356]	validation_0-mlogloss:0.01076
# [357]	validation_0-mlogloss:0.01075
# [358]	validation_0-mlogloss:0.01074
# [359]	validation_0-mlogloss:0.01072
# [360]	validation_0-mlogloss:0.01072
# [361]	validation_0-mlogloss:0.01070
# [362]	validation_0-mlogloss:0.01069
# [363]	validation_0-mlogloss:0.01069
# [364]	validation_0-mlogloss:0.01067
# [365]	validation_0-mlogloss:0.01066
# [366]	validation_0-mlogloss:0.01065
# [367]	validation_0-mlogloss:0.01064
# [368]	validation_0-mlogloss:0.01062
# [369]	validation_0-mlogloss:0.01061
# [370]	validation_0-mlogloss:0.01060
# [371]	validation_0-mlogloss:0.01059
# [372]	validation_0-mlogloss:0.01058
# [373]	validation_0-mlogloss:0.01057
# [374]	validation_0-mlogloss:0.01056
# [375]	validation_0-mlogloss:0.01054
# [376]	validation_0-mlogloss:0.01053
# [377]	validation_0-mlogloss:0.01052
# [378]	validation_0-mlogloss:0.01051
# [379]	validation_0-mlogloss:0.01050
# [380]	validation_0-mlogloss:0.01049
# [381]	validation_0-mlogloss:0.01048
# [382]	validation_0-mlogloss:0.01047
# [383]	validation_0-mlogloss:0.01046
# [384]	validation_0-mlogloss:0.01045
# [385]	validation_0-mlogloss:0.01044
# [386]	validation_0-mlogloss:0.01043
# [387]	validation_0-mlogloss:0.01042
# [388]	validation_0-mlogloss:0.01041
# [389]	validation_0-mlogloss:0.01040
# [390]	validation_0-mlogloss:0.01039
# [391]	validation_0-mlogloss:0.01038
# [392]	validation_0-mlogloss:0.01037
# [393]	validation_0-mlogloss:0.01036
# [394]	validation_0-mlogloss:0.01035
# [395]	validation_0-mlogloss:0.01034
# [396]	validation_0-mlogloss:0.01033
# [397]	validation_0-mlogloss:0.01032
# [398]	validation_0-mlogloss:0.01031
# [399]	validation_0-mlogloss:0.01030
# 소요시간 :  ['0:01:53', '593056']
