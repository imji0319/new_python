# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import warnings 
from matplotlib import rc

warnings.filterwarnings('ignore')
plt.rcParams['axes.unicode_minus'] = False 
rc('font', family = 'NanumMyeongo')
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %%
train = pd.read_csv('parking_data/train.csv')
test = pd.read_csv('parking_data/test.csv')

# %%
train.단지코드.value_counts()
# Out:
# C1439    48
# C2132    47
# C1859    40
# C1790    33
# C2597    32
#          ..
# C1718     2
# C2437     1
# C2188     1
# C2520     1
# C2340     1
# Name: 단지코드, Length: 423, dtype: int64

# %%
except_D = train[train['자격유형'] != 'D']

# %%
except_D.단지코드.value_counts()
# Out:
# C2051    23
# C2538    19
# C2507    18
# C2506    17
# C1177    16
#          ..
# C2571     1
# C2520     1
# C2340     1
# C2188     1
# C2437     1
# Name: 단지코드, Length: 423, dtype: int64

# %%
except_D[except_D['단지코드'] == 'C2051']
# Out:
#        단지코드  총세대수 임대건물구분       지역       공급유형   전용면적  전용면적별세대수  공가수 자격유형  \
# 2426  C2051  1164    아파트  세종특별자치시  공공임대(10년)  59.39         2  0.0    A
# 2427  C2051  1164    아파트  세종특별자치시  공공임대(10년)  59.87        48  0.0    A
# 2428  C2051  1164    아파트  세종특별자치시  공공임대(10년)  59.87       241  0.0    A
# 2429  C2051  1164    아파트  세종특별자치시  공공임대(10년)  59.96         3  0.0    A
# 2430  C2051  1164    아파트  세종특별자치시  공공임대(10년)  65.39        24  0.0    A
# 2431  C2051  1164    아파트  세종특별자치시  공공임대(10년)  72.82        64  0.0    A
# 2432  C2051  1164    아파트  세종특별자치시  공공임대(10년)  74.55       267  0.0    A
# 2433  C2051  1164    아파트  세종특별자치시  공공임대(10년)  79.61         7  0.0    A
# 2434  C2051  1164    아파트  세종특별자치시  공공임대(10년)  79.74        35  0.0    A
# 2435  C2051  1164    아파트  세종특별자치시  공공임대(10년)  79.93         3  0.0    A
# 2436  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.32        22  0.0    A
# 2437  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.51         8  0.0    A
# 2438  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.58         2  0.0    A
# 2439  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.59        10  0.0    A
# 2440  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.82         6  0.0    A
# 2441  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.82        23  0.0    A
# 2442  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.86       163  0.0    A
# 2443  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.89         3  0.0    A
# 2444  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.91       126  0.0    A
# 2445  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.92        87  0.0    A
# 2446  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.93         2  0.0    A
# 2447  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.93         6  0.0    A
# 2448  C2051  1164    아파트  세종특별자치시  공공임대(10년)  84.93        12  0.0    A
#
#          임대보증금     임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  \
# 2426  39000000  440000                           0.0                 3.0
# 2427  39000000  440000                           0.0                 3.0
# 2428  39000000  440000                           0.0                 3.0
# 2429  39000000  440000                           0.0                 3.0
# 2430  39000000  480000                           0.0                 3.0
# 2431  49000000  520000                           0.0                 3.0
# 2432  49000000  535000                           0.0                 3.0
# 2433  55000000  570000                           0.0                 3.0
# 2434  55000000  570000                           0.0                 3.0
# 2435  55000000  570000                           0.0                 3.0
# 2436  61000000  585000                           0.0                 3.0
# 2437  61000000  585000                           0.0                 3.0
# 2438  61000000  590000                           0.0                 3.0
# 2439  63000000  590000                           0.0                 3.0
# 2440  61000000  585000                           0.0                 3.0
# 2441  61000000  585000                           0.0                 3.0
# 2442  61000000  585000                           0.0                 3.0
# 2443  65000000  590000                           0.0                 3.0
# 2444  61000000  585000                           0.0                 3.0
# 2445  61000000  585000                           0.0                 3.0
# 2446  61000000  590000                           0.0                 3.0
# 2447  65000000  590000                           0.0                 3.0
# 2448  65000000  590000                           0.0                 3.0
#
#       단지내주차면수  등록차량수
# 2426    755.0  780.0
# 2427    755.0  780.0
# 2428    755.0  780.0
# 2429    755.0  780.0
# 2430    755.0  780.0
# 2431    755.0  780.0
# 2432    755.0  780.0
# 2433    755.0  780.0
# 2434    755.0  780.0
# 2435    755.0  780.0
# 2436    755.0  780.0
# 2437    755.0  780.0
# 2438    755.0  780.0
# 2439    755.0  780.0
# 2440    755.0  780.0
# 2441    755.0  780.0
# 2442    755.0  780.0
# 2443    755.0  780.0
# 2444    755.0  780.0
# 2445    755.0  780.0
# 2446    755.0  780.0
# 2447    755.0  780.0
# 2448    755.0  780.0

# %% [markdown]
# 자격유형이 D가 아닌 경우에도 단지코드별 가지는 데이터 수가 다름.
