# %% [markdown]
# # 한국 부동산 데이터 시각화

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc 
import seaborn as sns

# %%
# 그래프 한글 처리 

rc('font', family = 'NanumMyeongjo')
plt.rcParams['axes.unicode_minus'] = False

# columns view 수정
pd.set_option('display.max_columns', None)

# %%
건축허가현황 = pd.read_csv('RealEstate_dataset/건축허가현황.csv')
국내건설수주액 = pd.read_csv('RealEstate_dataset/국내건설수주액.csv')
미분양주택현황 = pd.read_csv('RealEstate_dataset/미분양주택현황.csv')
아파트실거래가격지수 = pd.read_csv('RealEstate_dataset/아파트 실거래가격지수.csv')
유형별_주택월세통합가격지수 = pd.read_csv('RealEstate_dataset/유형별_주택월세통합가격지수.csv')
주택건설인허가실적 = pd.read_csv('RealEstate_dataset/주택건설인허가실적.csv')
주택매매가격지수 = pd.read_csv('RealEstate_dataset/주택매매가격지수(KB).csv')
주택전세가격지수 = pd.read_csv('RealEstate_dataset/주택전세가격지수(KB).csv')
지역별_지가변동률 = pd.read_csv('RealEstate_dataset/지역별_지가변동률.csv')

# %% [markdown]
# ## 1. 제공 데이터 기본 확인

# %% [markdown]
# ### 1-1. 건축허가현황

# %%
건축허가현황.head(3)
# Out:
#    Unnamed: 0  연면적-철근·철골조[㎡]  연면적-조적조[㎡]  연면적-목조[㎡]  연면적-기타(자재별)[㎡]  \
# 0  2000-08-01      3898712.0    122063.0     5229.0        287185.0
# 1  2000-09-01      3055754.0    113586.0     5918.0        236449.0
# 2  2000-10-01      4104565.0    134648.0     8006.0        314620.0
#
#    연면적-주거용[㎡]  연면적-상업용[㎡]  연면적-공업용[㎡]  연면적-교육및사회용[㎡]  연면적-기타(용도별)[㎡]  \
# 0   1812355.0   1088979.0    687577.0            0.0        724278.0
# 1   1273430.0   1014900.0    702592.0            0.0        420785.0
# 2   1908535.0   1095874.0   1011477.0            0.0        545953.0
#
#    연면적-자재별[㎡]  연면적-용도별[㎡]  동수-철근·철골조[동수]  동수-조적조[동수]  동수-목조[동수]  \
# 0   4313189.0   4313189.0         4319.0      1216.0       58.0
# 1   3411707.0   3411707.0         3910.0      1128.0       70.0
# 2   4561839.0   4561839.0         4970.0      1290.0       61.0
#
#    동수-기타(자재별)[동수]  동수-주거용[동수]  동수-상업용[동수]  동수-공업용[동수]  동수-교육및사회용[동수]  \
# 0          1078.0      2905.0      2008.0       741.0            0.0
# ...

# %%
건축허가현황.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      247 non-null    object
#  1   연면적-철근·철골조[㎡]   247 non-null    float64
#  2   연면적-조적조[㎡]      247 non-null    float64
#  3   연면적-목조[㎡]       247 non-null    float64
#  4   연면적-기타(자재별)[㎡]  247 non-null    float64
#  5   연면적-주거용[㎡]      247 non-null    float64
#  6   연면적-상업용[㎡]      247 non-null    float64
#  7   연면적-공업용[㎡]      247 non-null    float64
#  8   연면적-교육및사회용[㎡]   247 non-null    float64
#  9   연면적-기타(용도별)[㎡]  247 non-null    float64
#  10  연면적-자재별[㎡]      247 non-null    float64
#  11  연면적-용도별[㎡]      247 non-null    float64
#  12  동수-철근·철골조[동수]   247 non-null    float64
#  13  동수-조적조[동수]      247 non-null    float64
#  14  동수-목조[동수]       247 non-null    float64
#  15  동수-기타(자재별)[동수]  247 non-null    float64
#  16  동수-주거용[동수]      247 non-null    float64
# ...

# %%
건축허가현황 = 건축허가현황.rename(columns = {'Unnamed: 0' : '연월'})

# %%
건축허가현황.head(2)
# Out:
#            연월  연면적-철근·철골조[㎡]  연면적-조적조[㎡]  연면적-목조[㎡]  연면적-기타(자재별)[㎡]  \
# 0  2000-08-01      3898712.0    122063.0     5229.0        287185.0
# 1  2000-09-01      3055754.0    113586.0     5918.0        236449.0
#
#    연면적-주거용[㎡]  연면적-상업용[㎡]  연면적-공업용[㎡]  연면적-교육및사회용[㎡]  연면적-기타(용도별)[㎡]  \
# 0   1812355.0   1088979.0    687577.0            0.0        724278.0
# 1   1273430.0   1014900.0    702592.0            0.0        420785.0
#
#    연면적-자재별[㎡]  연면적-용도별[㎡]  동수-철근·철골조[동수]  동수-조적조[동수]  동수-목조[동수]  \
# 0   4313189.0   4313189.0         4319.0      1216.0       58.0
# 1   3411707.0   3411707.0         3910.0      1128.0       70.0
#
#    동수-기타(자재별)[동수]  동수-주거용[동수]  동수-상업용[동수]  동수-공업용[동수]  동수-교육및사회용[동수]  \
# 0          1078.0      2905.0      2008.0       741.0            0.0
# 1           793.0      2653.0      1756.0       652.0            0.0
#
#    동수-기타(용도별)[동수]  동수-자재별[동수]  동수-용도별[동수]
# 0          1017.0      6671.0      6671.0
# 1           840.0      5901.0      5901.0

# %%
건축허가현황['연월'] = pd.to_datetime(건축허가현황['연월'],
                          format = '%Y-%m-%d')

# %%
plt.figure(figsize = (15,8))
plt.plot('연월', '연면적-주거용[㎡]', data = 건축허가현황, label = '주거용 면적')
plt.plot('연월', '연면적-상업용[㎡]', data = 건축허가현황, label = '상업용 면적')
plt.plot('연월', '연면적-공업용[㎡]', data = 건축허가현황, label = '공업용 면적')
plt.legend()
plt.xlabel('연월')
plt.ylabel('연면적 [㎡]')
plt.title('건축허가 변화 현황', size = 15, pad = 10)
# Out:
# Text(0.5, 1.0, '건축허가 변화 현황')

# %% [markdown]
# ### 1-2. 국내건설수주액

# %%
국내건설수주액.head(3)
# Out:
#            연월  총수주액[백만원]  공공부문[백만원]  중앙정부[백만원]  지방자치단체[백만원]  공기업[백만원]  \
# 0  1976-01-01    12592.0     9664.0     2037.0       3844.0    3243.0
# 1  1976-02-01     8230.0     4156.0      797.0       1954.0    1216.0
# 2  1976-03-01    22261.0    14173.0     1864.0       4764.0    7078.0
#
#    기타공공단체[백만원]  민간부문[백만원]  제조업[백만원]  비제조업[백만원]  국내외국기관[백만원]  민자[백만원]  건축[백만원]  \
# 0        540.0     2928.0    2434.0      494.0          NaN      NaN   2231.0
# 1        189.0     4074.0    1760.0     2314.0          NaN      NaN   3762.0
# 2        467.0     7419.0    4060.0     3359.0        669.0      NaN  11678.0
#
#    주택[백만원]  사무실 및 점포[백만원]  공장 및 창고[백만원]  관공서[백만원]  기타[백만원]  토목[백만원]  \
# 0    186.0          928.0         862.0     239.0     16.0  10361.0
# 1    246.0          847.0        1955.0      85.0    629.0   4468.0
# 2   3706.0         2217.0        3454.0    1308.0    993.0  10583.0
#
#    치산 및 치수[백만원]  농림 및 수산[백만원]  도로 및 교량[백만원]  항만 및 공항[백만원]  철도 및 궤도[백만원]  \
# ...

# %%
국내건설수주액 = 국내건설수주액.rename(columns = {'Unnamed: 0' : '연월'})

# %%
국내건설수주액['연월'] = pd.to_datetime(국내건설수주액['연월'],
                          format = '%Y-%m-%d')

# %%
plt.figure(figsize = (15,8))
plt.plot('연월', '총수주액[백만원]', data = 국내건설수주액)
plt.legend()
plt.xlabel('연월')
plt.ylabel('총 수주액[백만원]')
plt.title('국내 총 수주액(백만원)', size = 15, pad = 10)
# Out:
# Text(0.5, 1.0, '국내 총 수주액(백만원)')

# %% [markdown]
# #### KOSPI지수와 비교

# %%
from pandas_datareader import data as pdr
import yfinance as yf

yf.pdr_override()

# %%
kospi = pdr.get_data_yahoo('^KS11', '1976-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
kospi.head(2)
# Out:
#                   Open       High         Low       Close   Adj Close  Volume
# Date
# 1996-12-11  705.989990  709.47998  704.429993  704.679993  704.679993   28000
# 1996-12-12  705.109985  706.01001  688.739990  689.380005  689.380005   25900

# %%
kospi.reset_index(inplace = True)

# %%
kospi['연월'] = pd.to_datetime(kospi['Date']).dt.strftime('%Y-%m')

# %%
kospi.head(2)
# Out:
#         Date        Open       High         Low       Close   Adj Close  \
# 0 1996-12-11  705.989990  709.47998  704.429993  704.679993  704.679993
# 1 1996-12-12  705.109985  706.01001  688.739990  689.380005  689.380005
#
#    Volume       연월
# 0   28000  1996-12
# 1   25900  1996-12

# %%
kospi['주식규모'] = kospi['Adj Close'] * kospi['Volume']

# %%
kospi1997= kospi[kospi['Date'].dt.year > 1996][['Adj Close','주식규모','연월']]

# %%
grouped = kospi1997.groupby(['연월'])

# %%
kospiadjClose = grouped.mean()

# %%
kospiadjClose = kospiadjClose.reset_index()

# %%
kospiadjClose.head(5)
# Out:
#         연월   Adj Close          주식규모
# 0  1997-01  669.451901  2.265398e+07
# 1  1997-02  698.520524  2.336594e+07
# 2  1997-03  657.586193  2.301644e+07
# 3  1997-04  693.637720  2.834394e+07
# 4  1997-05  712.754208  3.631196e+07

# %%
kospiadjClose.shape
# Out:
# (293, 3)

# %%
# 연월별 총수주액 데이터 셋과 kospi 평균 데이터 셋 결합 

tmp = 국내건설수주액[국내건설수주액['연월'].dt.year > 1996][['연월','총수주액[백만원]']]

# %%
tmp['연월'] = pd.to_datetime(tmp['연월']).dt.strftime('%Y-%m')

# %%
tmp.head(3)
# Out:
#           연월  총수주액[백만원]
# 252  1997-01  2630388.0
# 253  1997-02  4450641.0
# 254  1997-03  6597689.0

# %%
temp = pd.merge(kospiadjClose, tmp, on = '연월', how ='inner')

# %%
temp['연월'] = pd.to_datetime(temp['연월'], format = '%Y-%m')

# %%
temp.set_index('연월', inplace = True)

# %%
temp['총수주액[만원]'] = temp['총수주액[백만원]']* 100
temp['총수주액[십만원]'] = temp['총수주액[백만원]']* 10
temp['총수주액[천만원]'] = temp['총수주액[백만원]']/ 10

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 290 entries, 1997-01-01 to 2021-02-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  290 non-null    float64
#  1   주식규모       290 non-null    float64
#  2   총수주액[백만원]  290 non-null    float64
#  3   총수주액[만원]   290 non-null    float64
#  4   총수주액[십만원]  290 non-null    float64
#  5   총수주액[천만원]  290 non-null    float64
# dtypes: float64(6)
# memory usage: 15.9 KB

# %%
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates


fig, ax = plt.subplots(figsize = (25,7))
plt.plot('총수주액[만원]', data = temp, label ='국내건설 총수주액[만원]')
plt.plot('주식규모', data = temp, label = '대한민국 주식시장(Adj Close * Volumn)')
plt.legend(fontsize = 12)


date_form = DateFormatter("%Y-%m")
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=30))
plt.xticks(rotation = 45)


plt.xlabel('연월')
plt.title('국내건설 총 수주액과 국내 주식시장의 관계 ', size = 20, pad = 12)
# Out:
# Text(0.5, 1.0, '국내건설 총 수주액과 국내 주식시장의 관계 ')

# %% [markdown]
# ### 1-4. 미분양주택현황

# %%
미분양주택현황.head(3)
# Out:
#    Unnamed: 0    전국[호]  서울[호]   부산[호]   대구[호]  인천[호]   광주[호]   대전[호]   울산[호]  \
# 0  2007-01-01  75616.0  697.0  8680.0  9467.0  243.0  7005.0   819.0  1180.0
# 1  2007-02-01  73619.0  590.0  8653.0  9134.0  312.0  6246.0   803.0  1210.0
# 2  2007-03-01  73162.0  687.0  8548.0  9189.0  266.0  5905.0  1048.0  1687.0
#
#     경기[호]   강원[호]   충북[호]   충남[호]   전북[호]   전남[호]   경북[호]    경남[호]  제주[호]  \
# 0  3604.0  5312.0  2548.0  7449.0  5179.0  5374.0  6210.0  11772.0   77.0
# 1  3361.0  5344.0  2645.0  7363.0  5098.0  5253.0  5948.0  11563.0   96.0
# 2  2579.0  5801.0  2565.0  7446.0  5184.0  4887.0  5854.0  11328.0  188.0
#
#    수도권[호]  세종[호]
# 0  4544.0    NaN
# 1  4263.0    NaN
# 2  3532.0    NaN

# %%
미분양주택현황.rename(columns={'Unnamed: 0' : '날짜'}, inplace =True)

# %%
미분양주택현황.set_index(['날짜'], inplace =True)

# %%
미분양주택현황['세종[호]'].value_counts(dropna=False)
# Out:
# 0.0       67
# NaN       66
# 4.0        6
# 3.0        2
# 16.0       2
# 50.0       1
# 42.0       1
# 21.0       1
# 102.0      1
# 424.0      1
# 414.0      1
# 180.0      1
# 43.0       1
# 14.0       1
# 158.0      1
# 54.0       1
# 1299.0     1
# 697.0      1
# 478.0      1
# 302.0      1
# 1344.0     1
# 313.0      1
# 61.0       1
# 433.0      1
# 295.0      1
# 84.0       1
# 721.0      1
# 1275.0     1
# 619.0      1
# 739.0      1
# 897.0      1
# 211.0      1
# Name: 세종[호], dtype: int64

# %%
미분양주택현황.drop(['전국[호]', '수도권[호]'], axis =1).plot(figsize = (25, 8))
plt.title('지역별 미분양 주택현황', size = 20, pad = 15)
# Out:
# Text(0.5, 1.0, '지역별 미분양 주택현황')

# %% [markdown]
# ### 1-5. 아파트실거래가격지수

# %%
아파트실거래가격지수.head(3)
# Out:
#    Unnamed: 0  도심권[2017.11=100]  동북권[2017.11=100]  동남권[2017.11=100]  \
# 0  2006-01-01              59.3              59.0              62.0
# 1  2006-02-01              58.1              59.3              63.8
# 2  2006-03-01              59.5              59.5              66.4
#
#    부산[2017.11=100]  대구[2017.11=100]  인천[2017.11=100]  광주[2017.11=100]  \
# 0             49.7             62.5             62.4             54.2
# 1             49.4             62.6             62.8             53.9
# 2             49.1             62.4             63.2             53.8
#
#    대전[2017.11=100]  울산[2017.11=100]  세종[2017.11=100]  경기[2017.11=100]  \
# 0             76.1             48.8             69.8             69.2
# 1             75.6             48.9             69.7             70.5
# 2             74.9             49.8             72.9             71.4
#
#    강원[2017.11=100]  충북[2017.11=100]  충남[2017.11=100]  서북권[2017.11=100]  \
# ...

# %%
아파트실거래가격지수.rename(columns={'Unnamed: 0' : '날짜'}, inplace =True)

# %%
아파트실거래가격지수.set_index(['날짜'], inplace =True)

# %%
col_list = ['도심권','동북권','동남권','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','서북권','서남권','전북','전남','경북','경남','제주','광역시','지방광역시','지방도','전국','서울','수도권','지방']
아파트실거래가격지수.columns = col_list

# %%
아파트실거래가격지수.plot(figsize = (25,8))

# %%
아파트실거래가격지수[['도심권','동북권','동남권','서북권','서남권','수도권']].plot(figsize=(25,6))
plt.axhline(y=100, color='black', linestyle='-', label = '2017-11 = 100')
plt.legend()
plt.show()

# %%
아파트실거래가격지수[['전국','수도권','지방']].plot(figsize=(25,6))
plt.axhline(y=100, color='black', linestyle='-', label = '2017-11 = 100')
plt.legend()

# %%
주택건설인허가실적.head(3)
# Out:
#    Unnamed: 0    전국[호]   부산[호]   충북[호]   충남[호]   대구[호]  대전[호]   강원[호]   광주[호]  \
# 0  2007-01-01  12038.0   455.0   188.0  1004.0   818.0   55.0   452.0  1022.0
# 1  2007-02-01  29789.0  1554.0   493.0  2310.0  3549.0   89.0   642.0  2200.0
# 2  2007-03-01  49827.0  3675.0  1187.0  4200.0  4596.0  154.0  1031.0  3547.0
#
#     경기[호]  ...   전북[호]   전남[호]   경북[호]   경남[호]  민간부문[호]  공공부문[호]   부문별[호]  \
# 0  2647.0  ...   888.0   206.0   698.0  1691.0  11718.0    320.0  12038.0
# 1  5517.0  ...  1490.0   700.0  2942.0  4206.0  28311.0   1478.0  29789.0
# 2  8705.0  ...  2153.0  1091.0  5256.0  6527.0  48285.0   1542.0  49827.0
#
#    세종[호]   서울[호]   울산[호]
# 0    NaN  1530.0   183.0
# 1    NaN  2324.0  1356.0
# 2    NaN  4212.0  2041.0
#
# [3 rows x 22 columns]

# %%
주택매매가격지수.head(3)
# Out:
#    Unnamed: 0  총지수[2019.01=100]  단독주택[2019.01=100]  연립주택[2019.01=100]  \
# 0  1986-01-01            34.656             61.347             43.053
# 1  1986-02-01            34.656             61.347             42.925
# 2  1986-03-01            34.708             61.513             42.733
#
#    아파트[2019.01=100]  아파트(서울)[2019.01=100]  총지수(서울)[2019.01=100]
# 0            20.973                17.153                30.044
# 1            20.973                17.183                30.044
# 2            20.935                17.153                30.002

# %%
주택전세가격지수.head(3)
# Out:
#    Unnamed: 0  총지수[2019.01=100]  단독주택[2019.01=100]  연립주택[2019.01=100]  \
# 0  1986-01-01            17.601             35.506             18.059
# 1  1986-02-01            17.853             35.731             18.155
# 2  1986-03-01            18.273             36.553             18.823
#
#    아파트[2019.01=100]  아파트(서울)[2019.01=100]  총지수(서울)[2019.01=100]
# 0            10.793                 9.782                16.755
# 1            11.104                10.195                17.066
# 2            11.446                10.550                17.573

# %%
지역별_지가변동률.head(3)
# Out:
#    Unnamed: 0  전국[%]  서울[%]  부산[%]  대구[%]  인천[%]  광주[%]  대전[%]  울산[%]  세종[%]  \
# 0  2005-01-01  0.226  0.192  0.083  0.212  0.145  0.156  0.196  0.137    NaN
# 1  2005-02-01  0.184  0.140  0.065  0.208  0.208  0.080  0.206  0.153    NaN
# 2  2005-03-01  0.348  0.403  0.119  0.278  0.470  0.154  0.674  0.180    NaN
#
#    경기[%]  강원[%]  충북[%]  충남[%]  전북[%]  전남[%]  경북[%]  경남[%]  제주[%]
# 0  0.374  0.142  0.221  0.463  0.108  0.099  0.163  0.140  0.150
# 1  0.256  0.169  0.178  0.531  0.084  0.071  0.135  0.160  0.111
# 2  0.324  0.257  0.227  1.154  0.085  0.139  0.161  0.225  0.102
